# %% [markdown]
# ## Drugbank Experimental Drug Harmonization
# #### ALL DATABASES ACCESSED 05/01/19
# ##### Author : Eryk Kropiwnicki | eryk.kropiwnicki@icahn.mssm.edu

# %%
import json
import pandas as pd
import xml.etree.ElementTree as et
import requests
import time
import pubchempy as pcp
from collections import defaultdict
import csv
import numpy as np

# %%
experimental_drugs = []

db_drugs = open('input/drug links-3.csv')
db_drugs_csv = csv.reader(db_drugs)
for row in db_drugs_csv:
    experimental_drugs.append(row[1].lower())
del experimental_drugs[0]

# %%
len(experimental_drugs)
# Out:
# 5764

# %% [markdown]
# ### VERIFY ALL COLLECTED DRUGS BY ASSOCIATION WITH ATTRIBUTES
# #### DATABASE FOR Synonyms, Pubchem IDs, SMILEs Strings, InChiKeys, and Molecular Formulas: https://pubchem.ncbi.nlm.nih.gov
# #### DATABASE FOR DRUGBANK ACCESSION NUMBERS: http://www.drugbank.ca
# #### OUTPUT FILES: drugbank_experimental_attributes.csv

# %%
# Retrieve all synonyms associated with each drug name #
failed = 0
synonym_dict = {}

for drug in experimental_drugs:
    url = 'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/'+str(drug)+ '/synonyms/JSON'
    response = requests.get(url)
    try:
        response.json()
    except ValueError:
        continue
    if 'InformationList' in response.json().keys():
        synonym = response.json()['InformationList']['Information'][0]['Synonym']
        synonym = [x.lower() for x in synonym]
        synonym_dict[drug] = synonym
    else:
        failed += 1
    time.sleep(1)

# %%
# Retreive all PubChemIDs for each drug #
failed = 0
cid_dict = {}

for drug in experimental_drugs:
    url = 'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/' + drug + '/cids/JSON'
    response = requests.get(url)
    if 'IdentifierList' in response.json().keys():
        cid = response.json()['IdentifierList']['CID'][0]
        cid_dict[drug] = str(cid)
    else:
        failed += 1
    time.sleep(0.50)

print(failed)
print(len(cid_dict))
# Out:
# 482
# 5283

# %%
# Construct a list of all PubChemIDs to query and retrieve drug attributes #
cid_list = []
for k,v in cid_dict.items():
    cid_list.append(v)

# %%
# Retrieving the Molecular Formula, SMILEs string, and InchiKey associated with each PubChemID #
failed = 0
smile_dict = {}
inchikey_dict = {}
molecularformula_dict = {}


for cid in cid_list:
    url ='https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/'+str(cid)+'/property/MolecularFormula,CanonicalSMILES,InChIKey/JSON'
    response = requests.get(url)
    try:
        response.json()
    except ValueError:
        continue
    if 'PropertyTable' in response.json().keys():
        smile = response.json()['PropertyTable']['Properties'][0]['CanonicalSMILES']
        inchikey = response.json()['PropertyTable']['Properties'][0]['InChIKey']
        molecularformula = response.json()['PropertyTable']['Properties'][0]['MolecularFormula']
        smile_dict[cid] = smile
        inchikey_dict[cid] = inchikey
        molecularformula_dict[cid] = molecularformula
        
    else:
        failed += 1
    time.sleep(1)

# %%
# Retrieve DrugBank Accession Numbers for each drug #
drugbank_ids = []
drugbank_drugs = []

drugbank = open('input/drug links-3.csv')
drugbank_csv = csv.reader(drugbank)
for row in drugbank_csv:
    drugbank_ids.append(row[0])
    drugbank_drugs.append(row[1].lower())

del drugbank_ids[0]
del drugbank_drugs[0]
                  
accession_dict = dict(zip(drugbank_drugs, drugbank_ids))

# %% [markdown]
# ### Creating a DataFrame with all DrugBank Experimental Drug Attributes
# #### Output File : Experimental_Drug_Attributes.csv

# %%
df = pd.DataFrame()
df = df.append(experimental_drugs)
df.columns = ['DrugBank Experimental Drugs']

# %%
# Add synonyms to dataframe #
synonyms = []

for index, row in df.iterrows():
    drugname = row.loc['DrugBank Experimental Drugs']
    if drugname in synonym_dict:
        synonyms.append(synonym_dict[drugname][1:])
    else:
        synonyms.append(None)
df.loc[:,'Synonyms'] = pd.Series(np.array(synonyms), index=df.index)

# %%
# Add PubChemIDs to dataframe #
pcids = []

for index,row in df.iterrows():
    drug = row.loc['DrugBank Experimental Drugs']
    if drug in cid_dict:
        pcids.append(cid_dict[drug])
    else:
        pcids.append(None)
df.loc[:,'PubChemID'] = pd.Series(np.array(pcids), index=df.index)

# %%
# Add SMILEs strings to dataframe #
SMILEs = []

for index, row in df.iterrows():
    pcid = row.loc['PubChemID']
    if pcid in smile_dict:
        SMILEs.append(smile_dict[pcid])
    else:
        SMILEs.append(None)
df.loc[:,'SMILEs'] = pd.Series(np.array(SMILEs), index=df.index)

# %%
# Add InChIKeys to dataframe #
InChIkeys = []

for index, row in df.iterrows():
    pcid = row.loc['PubChemID']
    if pcid in inchikey_dict:
        InChIkeys.append(inchikey_dict[pcid])
    else:
        InChIkeys.append(None)
df.loc[:,'InChIkeys'] = pd.Series(np.array(InChIkeys), index=df.index)

# %%
# Add Molecular Formulas to dataframe #
MFs = []

for index, row in df.iterrows():
    pcid = row.loc['PubChemID']
    if pcid in molecularformula_dict:
        MFs.append(molecularformula_dict[pcid])
    else:
        MFs.append(None)
df.loc[:,'Molecular Formula'] = pd.Series(np.array(MFs),index=df.index)

# %%
# Add Accession Numbers to dataframe #
AccNumber = []
for index, row in df.iterrows():
    drugname = row.loc['DrugBank Experimental Drugs']
    if drugname in accession_dict:
         AccNumber.append(accession_dict[drugname])
    else:  
        df.drop(index, inplace = True)   
df.loc[:,'DB_Accession_Numbers'] = pd.Series(np.array(AccNumber), index=df.index)

# %%
df
# Out:
#                             DrugBank Experimental Drugs  \
# 0                     indium in-111 satumomab pendetide
# 1                                           felypressin
# 2                         technetium tc-99m arcitumomab
# 3                                              spermine
# 4                                             pyridoxal
# 5                                             remikiren
# 6                                            reboxetine
# 7                                          clomocycline
# 8                                            picrotoxin
# 9                                            adinazolam
# 10                                           cinalukast
# 11                                         furazolidone
# 12                                          candoxatril
# 13                                         enprofylline
# 14                                            progabide
# 15                                        chlorphenesin
# 16                                           alprenolol
# 17                                        dirithromycin
# 18                                            cerulenin
# 19                      hydroxystilbamidine isethionate
# 20                                             mimosine
# 21                                          mequitazine
# 22                                           hesperetin
# 23                        desoxycorticosterone pivalate
# 24                                             ridogrel
# 25                                      chlorprothixene
# 26                                           bevantolol
# 27                                          cefamandole
# 28                         dihydroquinidine barbiturate
# 29                                           forasartan
# ...                                                 ...
# 5734                                          cortisone
# 5735                                        dextrorphan
# 5736                                   prezatide copper
# 5737                          chamaecyparis obtusa leaf
# 5738                             centella asiatica leaf
# 5739                              sambucus nigra flower
# 5740                                       rosemary oil
# 5741                                         ginger oil
# 5742                                        willow bark
# 5743                                       turmeric oil
# 5744                           atractylodes lancea root
# 5745                                         beef liver
# 5746                                ferric oxyhydroxide
# 5747  ethyl 8-hydroxy-alpha-(2-propynylamino)-5-quin...
# 5748                                sodium metavanadate
# 5749                    dexamethasone metasulfobenzoate
# 5750                                            ribitol
# 5751                                        ceramide ap
# 5752                                        ceramide ng
# 5753                                    tosylchloramide
# 5754                                       tenivastatin
# 5755                                          cinazepam
# 5756                                         clonazolam
# 5757                                         nitrazolam
# 5758                                          pyrazolam
# 5759                                         bentazepam
# 5760                                        brovanexine
# 5761                           riboflavin tetrabutyrate
# 5762                                            mebenil
# 5763                                       rebeccamycin
#
#                                                Synonyms  PubChemID  \
# 0                                                  None       None
# 1     [plv-2, felypressine, felypressinum, felipresi...   14257662
# 2                                                  None       None
# 3     [71-44-3, neuridine, gerontine, musculamine, s...       1103
# 4     [pyridoxaldehyde, 66-72-8, 3-hydroxy-5-(hydrox...       1050
# 5     [126222-34-2, remikiren [inn], unii-lc7fbl96a4...    6324659
# 6     [71620-89-8, norebox, vestra, 98769-81-4, (2r)...     127151
# 7     [chlormethylenecycline, clomocyclinum, clomoci...   54680675
# 8     [cocculin, 124-87-8, picrotoxin, powder, c15h1...    5311359
# 9     [adinazolamum, 37115-32-5, deracyn, adinazolam...      37632
# 10    [128312-51-6, cinalukast [usan:inn], ro 24-591...    6436135
# 11    [67-45-8, furoxone, nitrofurazolidone, furazol...    5323714
# 12    [123122-55-4, unii-acp75508ee, acp75508ee, che...    5362417
# 13    [3-propylxanthine, 3-n-propylxanthine, 41078-0...       1676
# 14    [halogabide, 62666-20-0, gabren, gabrene, prog...      44115
# 15    [104-29-0, 3-(4-chlorophenoxy)-1,2-propanediol...       7697
# 16    [alfeprol, alpheprol, alprenololum, 13655-52-2...       2119
# 17    [dirithromycine, dirithromycinum, diritromicin...    6473883
# 18    [17397-89-6, helicocerin, unii-mf286y830q, ein...    5282054
# 19    [2-hydroxystilbamidine isethionate, hydroxysti...  135577894
# 20    [leucenol, 10182-82-8, wznjwvwktvetcg-uhfffaoy...       3862
# 21    [29216-28-2, metaplexan, primalan, virginan, m...       4066
# 22    [520-33-2, hesperitin, 3',5,7-trihydroxy-4'-me...      72281
# 23    [deoxycortone pivalate, 808-48-0, docp, desoxy...   11876263
# 24    [ridogrelum, ridogrelum [inn-latin], unii-qts5...    5362391
# 25    [113-59-7, truxal, taractan, chlorprothixenum,...     667467
# 26    [59170-23-9, bevantololum, bevantololum [inn-l...       2372
# 27    [cefadole, cephamandole, 34444-01-4, cefamando...     456255
# 28                                                 None       None
# 29    [sc-52458, 145216-43-9, unii-065f7wpt0b, sc 52...     132706
# ...                                                 ...        ...
# 5734  [53-06-5, kendall's compound e, andreson, cort...     222786
# 5735  [dextrorphane, dextrorphanum, d-3-hydroxy-n-me...    5360697
# 5736  [unii-6bjq43t1i9, 6bjq43t1i9, 89030-95-5, ghk ...   71587328
# 5737                                               None       None
# 5738                                               None       None
# 5739                                               None       None
# 5740                                               None       None
# 5741                                               None       None
# 5742                                               None       None
# 5743  [458-37-7, diferuloylmethane, natural yellow 3...     969516
# 5744                                               None       None
# 5745                                               None       None
# 5746                                               None       None
# 5747  [m-31, ethyl 8-hydroxy-alpha-(2-propynylamino)...   10424768
# 5748  [13718-26-8, sodium vanadate(v), vanadic acid,...    4148882
# 5749                                               None       None
# 5750  [ribitol, adonitol, xylite, d-xylitol, 87-99-0...       6912
# 5751  [cer(t18:0/18:0(2oh)), n-(2-hydroxyoctadecanoy...   44625889
# 5752                                               None       None
# 5753                                               None       None
# 5754  [tenivastatin, 121009-77-6, unii-9l6m5th46b, d...      64718
# 5755  [172986-25-3, butanedioic acid, mono(7-bromo-5...     629281
# 5756  [unii-hjh52yyc1x, hjh52yyc1x, 33887-02-4, sche...   12317881
# 5757  [k499dbb308, 28910-99-8, nitrazolam, 4h-(1,2,4...   20317278
# 5758  [39243-02-2, unii-8lh16383pk, 8lh16383pk, 8-br...   12562545
# 5759  [thiadipone, tiadipone, bentazepam [usan:inn],...  135412795
# 5760  [unii-y00sd533iw, y00sd533iw, 54340-61-3, brov...     162137
# 5761  [unii-f211c9msgy, hibon, ccris 5849, 752-56-7,...      92140
# 5762  [2-methyl-n-phenylbenzamide, 2-methylbenzanili...      23466
# 5763  [93908-02-2, nsc 359079, brn 4732638, unii-y96...      73110
#
#                                                  SMILEs  \
# 0                                                  None
# 1     C1CC(N(C1)C(=O)C2CSSCC(C(=O)NC(C(=O)NC(C(=O)NC...
# 2                                                  None
# 3                                      C(CCNCCCN)CNCCCN
# 4                                CC1=NC=C(C(=C1O)C=O)CO
# 5     CC(C)(C)S(=O)(=O)CC(CC1=CC=CC=C1)C(=O)NC(CC2=C...
# 6                 CCOC1=CC=CC=C1OC(C2CNCCO2)C3=CC=CC=C3
# 7     CC1(C2CC3C(C(=O)C(=C(C3(C(=O)C2=C(C4=C(C=CC(=C...
# 8     CC(=C)C1C2C3C4(C(C1C(=O)O2)(CC5C4(O5)C(=O)O3)O...
# 9     CN(C)CC1=NN=C2N1C3=C(C=C(C=C3)Cl)C(=NC2)C4=CC=...
# 10    CCC(CC)(CC(=O)NC1=CC=CC(=C1)C=CC2=NC(=CS2)C3CC...
# 11                C1COC(=O)N1N=CC2=CC=C(O2)[N+](=O)[O-]
# 12    COCCOCC(CC1(CCCC1)C(=O)NC2CCC(CC2)C(=O)O)C(=O)...
# 13                           CCCN1C2=C(C(=O)NC1=O)NC=N2
# 14       C1=CC(=CC=C1C(=NCCCC(=O)N)C2=C(C=CC(=C2)F)O)Cl
# 15                              C1=CC(=CC=C1OCC(CO)O)Cl
# 16                         CC(C)NCC(COC1=CC=CC=C1CC=C)O
# 17    CCC1C(C2C(C(C(CC(C(C(C(C(C(=O)O1)C)OC3CC(C(C(O...
# 18                         CC=CCC=CCCC(=O)C1C(O1)C(=O)N
# 19    C1=CC(=CC=C1C=CC2=C(C=C(C=C2)C(=N)N)O)C(=N)N.C...
# 20                         C1=CN(C=C(C1=O)O)CC(C(=O)O)N
# 21            C1CN2CCC1C(C2)CN3C4=CC=CC=C4SC5=CC=CC=C53
# 22        COC1=C(C=C(C=C1)C2CC(=O)C3=C(C=C(C=C3O2)O)O)O
# 23    CC12CCC3C(C1CCC2C(=O)COC(=O)C(C)(C)C)CCC4=CC(=...
# 24    C1=CC(=CC(=C1)C(F)(F)F)C(=NOCCCCC(=O)O)C2=CN=C...
# 25              CN(C)CCC=C1C2=CC=CC=C2SC3=C1C=C(C=C3)Cl
# 26          CC1=CC(=CC=C1)OCC(CNCCC2=CC(=C(C=C2)OC)OC)O
# 27    CN1C(=NN=N1)SCC2=C(N3C(C(C3=O)NC(=O)C(C4=CC=CC...
# 28                                                 None
# 29    CCCCC1=NN(C(=N1)CCCC)CC2=CN=C(C=C2)C3=CC=CC=C3...
# ...                                                 ...
# 5734   CC12CCC(=O)C=C1CCC3C2C(=O)CC4(C3CCC4(C(=O)CO)O)C
# 5735                   CN1CCC23CCCCC2C1CC4=C3C=C(C=C4
# <b>limit_output extension: Maximum message size of 10000 exceeded with 17379 characters</b>

# %%
# Export all drug attributes as a dataframe #
df.to_csv('/Users/maayanlab/Documents/DrugSetEnrichment/Drugsetlibraries/Drugbank/Experimental/drugbank_experimental_drug_attributes.csv')
