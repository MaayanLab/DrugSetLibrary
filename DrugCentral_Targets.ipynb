# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
from scipy.spatial.distance import squareform, pdist,jaccard
import sys,  datetime, os
import requests
import chardet

# %% [markdown]
# ## Load Data

# %% [markdown]
# #### Load DrugCentral Data

# %%
df = pd.read_table('Input/drugcentral_targets.tsv')

# %%
df.head()
# Out:
#          DRUG_NAME  STRUCT_ID  \
# 0  levobupivacaine          4
# 1  levobupivacaine          4
# 2  levobupivacaine          4
# 3  levobupivacaine          4
# 4  levobupivacaine          4
#
#                                          TARGET_NAME TARGET_CLASS ACCESSION  \
# 0        Sodium channel protein type 4 subunit alpha  Ion channel    P35499
# 1                                Cytochrome P450 2D6       Enzyme    P10635
# 2  Potassium voltage-gated channel subfamily H me...  Ion channel    Q12809
# 3  Potassium voltage-gated channel subfamily D me...  Ion channel    Q9UK17
# 4              Prostaglandin E2 receptor EP1 subtype         GPCR    P34995
#
#      GENE    SWISSPROT  ACT_VALUE  ACT_UNIT ACT_TYPE  \
# 0   SCN4A  SCN4A_HUMAN        NaN       NaN      NaN
# 1  CYP2D6  CP2D6_HUMAN   6.706859       NaN     IC50
# 2   KCNH2  KCNH2_HUMAN   4.890000       NaN     IC50
# 3   KCND3  KCND3_HUMAN   4.500000       NaN     IC50
# 4  PTGER1  PE2R1_HUMAN        NaN       NaN      NaN
#
#                                          ACT_COMMENT   ACT_SOURCE RELATION  \
# 0                                                NaN    WOMBAT-PK      NaN
# 1  DRUGMATRIX: CYP450, 2D6 enzyme inhibition (sub...  DRUG MATRIX        =
# 2  Inhibition of wild-type human ERG channel expr...       CHEMBL        =
# 3                                                NaN    WOMBAT-PK        =
# 4                                                NaN    WOMBAT-PK      NaN
#
#    MOA MOA_SOURCE                                     ACT_SOURCE_URL  \
# 0  1.0     CHEMBL                                                NaN
# 1  NaN        NaN                                                NaN
# 2  NaN        NaN  https://www.ebi.ac.uk/chembl/compound/inspect/...
# 3  NaN        NaN                                                NaN
# 4  NaN        NaN                                                NaN
#
#                                       MOA_SOURCE_URL ACTION_TYPE    TDL  \
# 0  https://www.ebi.ac.uk/chembl/compound/inspect/...     BLOCKER  Tclin
# 1                                                NaN         NaN  Tclin
# 2                                                NaN         NaN  Tclin
# 3                                                NaN         NaN  Tclin
# 4                                                NaN         NaN  Tclin
#
#        ORGANISM
# 0  Homo sapiens
# 1  Homo sapiens
# 2  Homo sapiens
# 3  Homo sapiens
# 4  Homo sapiens

# %%
df.shape
# Out:
# (16289, 20)

# %%
df = df.dropna(subset=['GENE'])

# %%
for index, row in df.iterrows():
    
    print(type(row.values))
    break
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# #### Load Targets Mapping File

# %%
target_update = pd.read_table('Input/mappingFile_2017.txt', names = ['Old Targets','Updated Targets'], engine='python')

# %%
target_update.head()
# Out:
#   Old Targets Updated Targets
# 0        A1BG            A1BG
# 1    A1BG-AS1        A1BG-AS1
# 2  NCRNA00181        A1BG-AS1
# 3      A1BGAS        A1BG-AS1
# 4     A1BG-AS        A1BG-AS1

# %% [markdown]
# #### Load LINCS Small Molecules

# %%
lincs = pd.read_csv('Input/LINCS_SmallMolecules.csv',encoding='ISO-8859-1')

# %%
lincs.head()
# Out:
#                      SM_Name SM_LINCS_ID SM_Alternative_Name  SM_PubChem_CID  \
# 0                Dichlobenil   LSM-19017                 NaN          3031.0
# 1                   AC1NWAJC   LSM-43967       Vulpinic acid       5701993.0
# 2  Sinapic Acid Methyl Ether   LSM-44124                 NaN        735755.0
# 3               Ferulic acid   LSM-44126        Ferulic acid        445858.0
# 4    Pinosylvin Methyl Ether   LSM-43902                 NaN       5281719.0
#
#                                  SM_SMILES_Parent  SM_SMILES_Batch  \
# 0                               Clc1cccc(Cl)c1C#N              NaN
# 1  COC(=O)\C(=C\1/OC(=O)C(C1=O)c2ccccc2)\c3ccccc3              NaN
# 2                   COc1cc(\C=C\C(=O)O)cc(OC)c1OC              NaN
# 3                        COc1cc(\C=C\C(=O)O)ccc1O              NaN
# 4                    COc1cc(O)cc(\C=C\c2ccccc2)c1              NaN
#
#                                      SM_InChi_Parent  SM_Molecular_Mass  \
# 0    InChI=1S/C7H3Cl2N/c8-6-2-1-3-7(9)5(6)4-10/h1-3H             172.01
# 1  InChI=1S/C19H14O5/c1-23-18(21)15(13-10-6-3-7-1...             322.31
# 2  InChI=1S/C12H14O5/c1-15-9-6-8(4-5-11(13)14)7-1...             238.24
# 3  InChI=1S/C10H10O4/c1-14-9-6-7(2-4-8(9)11)3-5-1...             194.18
# 4  InChI=1S/C15H14O2/c1-17-15-10-13(9-14(16)11-15...             226.27
#
#   MOLECULAR_FORMULA SM_ChEBI_ID
# 0          C7H3Cl2N         943
# 1          C19H14O5         NaN
# 2          C12H14O5         NaN
# 3          C10H10O4       17620
# 4          C15H14O2        8227

# %% [markdown]
# ## Fix DrugCentral GENE column

# %%
how_many = 0
appended_df = []
gene_index = np.where(df.columns.values=='GENE')[0][0]

for index, row in df.iterrows():
    gene_group = row.loc['GENE']
    if '|' in gene_group:
        gene_split = gene_group.split('|')
        for i in gene_split:
            row_as_list = row.values.tolist()
            row_as_list[gene_index] = i
            appended_df.append(row_as_list)
    df.drop(index, inplace = True)

print(appended_df)
# Out:
# [['(S)-nicardipine', 5, 'Voltage-gated L-type calcium channel', 'Ion channel', 'Q01668|Q13936', 'CACNA1C', 'CAC1C_HUMAN|CAC1D_HUMAN', nan, nan, nan, 'Mechanism of Action', 'DRUG LABEL', nan, 1.0, 'DRUG LABEL', 'http://www.accessdata.fda.gov/drugsatfda_docs/label/2009/022276s003lbl.pdf', 'http://www.accessdata.fda.gov/drugsatfda_docs/label/2009/022276s003lbl.pdf', 'BLOCKER', 'Tclin|Tclin', 'Homo sapiens'], ['(S)-nicardipine', 5, 'Voltage-gated L-type calcium channel', 'Ion channel', 'Q01668|Q13936', 'CACNA1D', 'CAC1C_HUMAN|CAC1D_HUMAN', nan, nan, nan, 'Mechanism of Action', 'DRUG LABEL', nan, 1.0, 'DRUG LABEL', 'http://www.accessdata.fda.gov/drugsatfda_docs/label/2009/022276s003lbl.pdf', 'http://www.accessdata.fda.gov/drugsatfda_docs/label/2009/022276s003lbl.pdf', 'BLOCKER', 'Tclin|Tclin', 'Homo sapiens'], ['acamprosate', 38, 'Glutamate [NMDA] receptor', 'Ion channel', 'O15399|O60391|Q05586|Q12879|Q13224|Q14957|Q8TCU5', 'GRIN1', 'NMD3A_HUMAN|NMD3B_HUMAN|NMDE1_HUMAN|NMDE2_HUMAN|NMDE3_HUMAN|NMDE4_HUMAN|NMDZ1_HUMAN', nan, nan, nan, 'Mechanism of Action; CHEMBL2094124; PROTEIN COMPLEX GROUP', 'CHEMBL', nan, 1.0, 'CHEMBL', 'https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1201293', 'https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1201293', 'ANTAGONIST', 'Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin', 'Homo sapiens'], ['acamprosate', 38, 'Glutamate [NMDA] receptor', 'Ion channel', 'O15399|O60391|Q05586|Q12879|Q13224|Q14957|Q8TCU5', 'GRIN2A', 'NMD3A_HUMAN|NMD3B_HUMAN|NMDE1_HUMAN|NMDE2_HUMAN|NMDE3_HUMAN|NMDE4_HUMAN|NMDZ1_HUMAN', nan, nan, nan, 'Mechanism of Action; CHEMBL2094124; PROTEIN COMPLEX GROUP', 'CHEMBL', nan, 1.0, 'CHEMBL', 'https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1201293', 'https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1201293', 'ANTAGONIST', 'Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin', 'Homo sapiens'], ['acamprosate', 38, 'Glutamate [NMDA] receptor', 'Ion channel', 'O15399|O60391|Q05586|Q12879|Q13224|Q14957|Q8TCU5', 'GRIN2B', 'NMD3A_HUMAN|NMD3B_HUMAN|NMDE1_HUMAN|NMDE2_HUMAN|NMDE3_HUMAN|NMDE4_HUMAN|NMDZ1_HUMAN', nan, nan, nan, 'Mechanism of Action; CHEMBL2094124; PROTEIN COMPLEX GROUP', 'CHEMBL', nan, 1.0, 'CHEMBL', 'https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1201293', 'https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1201293', 'ANTAGONIST', 'Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin', 'Homo sapiens'], ['acamprosate', 38, 'Glutamate [NMDA] receptor', 'Ion channel', 'O15399|O60391|Q05586|Q12879|Q13224|Q14957|Q8TCU5', 'GRIN2C', 'NMD3A_HUMAN|NMD3B_HUMAN|NMDE1_HUMAN|NMDE2_HUMAN|NMDE3_HUMAN|NMDE4_HUMAN|NMDZ1_HUMAN', nan, nan, nan, 'Mechanism of Action; CHEMBL2094124; PROTEIN COMPLEX GROUP', 'CHEMBL', nan, 1.0, 'CHEMBL', 'https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1201293', 'https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1201293', 'ANTAGONIST', 'Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin', 'Homo sapiens'], ['acamprosate', 38, 'Glutamate [NMDA] receptor', 'Ion channel', 'O15399|O60391|Q05586|Q12879|Q13224|Q14957|Q8TCU5', 'GRIN2D', 'NMD3A_HUMAN|NMD3B_HUMAN|NMDE1_HUMAN|NMDE2_HUMAN|NMDE3_HUMAN|NMDE4_HUMAN|NMDZ1_HUMAN', nan, nan, nan, 'Mechanism of Action; CHEMBL2094124; PROTEIN COMPLEX GROUP', 'CHEMBL', nan, 1.0, 'CHEMBL', 'https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1201293', 'https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1201293', 'ANTAGONIST', 'Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin', 'Homo sapiens'], ['acamprosate', 38, 'Glutamate [NMDA] receptor', 'Ion channel', 'O15399|O60391|Q05586|Q12879|Q13224|Q14957|Q8TCU5', 'GRIN3A', 'NMD3A_HUMAN|NMD3B_HUMAN|NMDE1_HUMAN|NMDE2_HUMAN|NMDE3_HUMAN|NMDE4_HUMAN|NMDZ1_HUMAN', nan, nan, nan, 'Mechanism of Action; CHEMBL2094124; PROTEIN COMPLEX GROUP', 'CHEMBL', nan, 1.0, 'CHEMBL', 'https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1201293', 'https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1201293', 'ANTAGONIST', 'Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin', 'Homo sapiens'], ['acamprosate', 38, 'Glutamate [NMDA] receptor', 'Ion chan ...

# %%
columnnames = list(df.columns.values)
fix_gene_df = pd.DataFrame(appended_df,columns = columnnames)

# %%
fix_gene_df.head()
# Out:
#          DRUG_NAME  STRUCT_ID                           TARGET_NAME  \
# 0  (S)-nicardipine          5  Voltage-gated L-type calcium channel
# 1  (S)-nicardipine          5  Voltage-gated L-type calcium channel
# 2      acamprosate         38             Glutamate [NMDA] receptor
# 3      acamprosate         38             Glutamate [NMDA] receptor
# 4      acamprosate         38             Glutamate [NMDA] receptor
#
#   TARGET_CLASS                                         ACCESSION     GENE  \
# 0  Ion channel                                     Q01668|Q13936  CACNA1C
# 1  Ion channel                                     Q01668|Q13936  CACNA1D
# 2  Ion channel  O15399|O60391|Q05586|Q12879|Q13224|Q14957|Q8TCU5    GRIN1
# 3  Ion channel  O15399|O60391|Q05586|Q12879|Q13224|Q14957|Q8TCU5   GRIN2A
# 4  Ion channel  O15399|O60391|Q05586|Q12879|Q13224|Q14957|Q8TCU5   GRIN2B
#
#                                            SWISSPROT  ACT_VALUE  ACT_UNIT  \
# 0                            CAC1C_HUMAN|CAC1D_HUMAN        NaN       NaN
# 1                            CAC1C_HUMAN|CAC1D_HUMAN        NaN       NaN
# 2  NMD3A_HUMAN|NMD3B_HUMAN|NMDE1_HUMAN|NMDE2_HUMA...        NaN       NaN
# 3  NMD3A_HUMAN|NMD3B_HUMAN|NMDE1_HUMAN|NMDE2_HUMA...        NaN       NaN
# 4  NMD3A_HUMAN|NMD3B_HUMAN|NMDE1_HUMAN|NMDE2_HUMA...        NaN       NaN
#
#   ACT_TYPE                                        ACT_COMMENT  ACT_SOURCE  \
# 0      NaN                                Mechanism of Action  DRUG LABEL
# 1      NaN                                Mechanism of Action  DRUG LABEL
# 2      NaN  Mechanism of Action; CHEMBL2094124; PROTEIN CO...      CHEMBL
# 3      NaN  Mechanism of Action; CHEMBL2094124; PROTEIN CO...      CHEMBL
# 4      NaN  Mechanism of Action; CHEMBL2094124; PROTEIN CO...      CHEMBL
#
#   RELATION  MOA  MOA_SOURCE  \
# 0      NaN  1.0  DRUG LABEL
# 1      NaN  1.0  DRUG LABEL
# 2      NaN  1.0      CHEMBL
# 3      NaN  1.0      CHEMBL
# 4      NaN  1.0      CHEMBL
#
#                                       ACT_SOURCE_URL  \
# 0  http://www.accessdata.fda.gov/drugsatfda_docs/...
# 1  http://www.accessdata.fda.gov/drugsatfda_docs/...
# 2  https://www.ebi.ac.uk/chembl/compound/inspect/...
# 3  https://www.ebi.ac.uk/chembl/compound/inspect/...
# 4  https://www.ebi.ac.uk/chembl/compound/inspect/...
#
#                                       MOA_SOURCE_URL ACTION_TYPE  \
# 0  http://www.accessdata.fda.gov/drugsatfda_docs/...     BLOCKER
# 1  http://www.accessdata.fda.gov/drugsatfda_docs/...     BLOCKER
# 2  https://www.ebi.ac.uk/chembl/compound/inspect/...  ANTAGONIST
# 3  https://www.ebi.ac.uk/chembl/compound/inspect/...  ANTAGONIST
# 4  https://www.ebi.ac.uk/chembl/compound/inspect/...  ANTAGONIST
#
#                                          TDL      ORGANISM
# 0                                Tclin|Tclin  Homo sapiens
# 1                                Tclin|Tclin  Homo sapiens
# 2  Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin  Homo sapiens
# 3  Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin  Homo sapiens
# 4  Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin  Homo sapiens

# %%
df.append(fix_gene_df)
# Out:
#                   DRUG_NAME  STRUCT_ID  \
# 0           (S)-nicardipine          5
# 1           (S)-nicardipine          5
# 2               acamprosate         38
# 3               acamprosate         38
# 4               acamprosate         38
# 5               acamprosate         38
# 6               acamprosate         38
# 7               acamprosate         38
# 8               acamprosate         38
# 9               acamprosate         38
# 10              acamprosate         38
# 11              acamprosate         38
# 12            acetazolamide         56
# 13            acetazolamide         56
# 14            acetazolamide         56
# 15            acetazolamide         56
# 16            acetazolamide         56
# 17            acetazolamide         56
# 18            acetazolamide         56
# 19            acetazolamide         56
# 20            acetazolamide         56
# 21            acetazolamide         56
# 22            acetazolamide         56
# 23            acetazolamide         56
# 24            acetazolamide         56
# 25            acetazolamide         56
# 26            acetazolamide         56
# 27            acetazolamide         56
# 28            acetazolamide         56
# 29            acetazolamide         56
# ...                     ...        ...
# 4665               anakinra       5017
# 4666               anakinra       5017
# 4667           sargramostim       5025
# 4668           sargramostim       5025
# 4669             oprelvekin       5026
# 4670             oprelvekin       5026
# 4671    denileukin diftitox       5087
# 4672    denileukin diftitox       5087
# 4673    denileukin diftitox       5087
# 4674  peginterferon beta-1a       5137
# 4675  peginterferon beta-1a       5137
# 4676     interferon beta-1a       5139
# 4677     interferon beta-1a       5139
# 4678     interferon beta-1b       5140
# 4679     interferon beta-1b       5140
# 4680  peginterferon alfa-2a       5158
# 4681  peginterferon alfa-2a       5158
# 4682  peginterferon alfa-2b       5164
# 4683  peginterferon alfa-2b       5164
# 4684            lifitegrast       5174
# 4685            lifitegrast       5174
# 4686          muromonab-CD3       5177
# 4687          muromonab-CD3       5177
# 4688          muromonab-CD3       5177
# 4689             brodalumab       5179
# 4690             brodalumab       5179
# 4691            crisaborole       5201
# 4692            crisaborole       5201
# 4693            crisaborole       5201
# 4694            crisaborole       5201
#
#                                             TARGET_NAME       TARGET_CLASS  \
# 0                  Voltage-gated L-type calcium channel        Ion channel
# 1                  Voltage-gated L-type calcium channel        Ion channel
# 2                             Glutamate [NMDA] receptor        Ion channel
# 3                             Glutamate [NMDA] receptor        Ion channel
# 4                             Glutamate [NMDA] receptor        Ion channel
# 5                             Glutamate [NMDA] receptor        Ion channel
# 6                             Glutamate [NMDA] receptor        Ion channel
# 7                             Glutamate [NMDA] receptor        Ion channel
# 8                             Glutamate [NMDA] receptor        Ion channel
# 9                GABA-A receptor alpha-1/beta-3/gamma-2        Ion channel
# 10               GABA-A receptor alpha-1/beta-3/gamma-2        Ion channel
# 11               GABA-A receptor alpha-1/beta-3/gamma-2        Ion channel
# 12                                   Carbonic anhydrase             Enzyme
# 13                                   Carbonic anhydrase             Enzyme
# 14                                   Carbonic anhydrase             Enzyme
# 15                                   Carbonic anhydrase             Enzyme
# 16                                   Carbonic anhydrase             Enzyme
# 17                                   Carbonic anhydrase             Enzyme
# 18                                   Carbonic anhydrase             Enzyme
# 19                                   Carbonic anhydrase             Enzyme
# 20                                   Carbonic anhydrase             Enzyme
# 21                                   Carbonic anhydrase             Enzyme
# 22                                   Carbonic anhydrase             Enzyme
# 23                                   Carbonic anhydrase             Enzyme
# 24                                 Carbonic anhydrase V             Enzyme
# 25                                 Carbonic anhydrase V             Enzyme
# 26                                   Carbonic anhydrase             Enzyme
# 27                                   Carbonic anhydrase             Enzyme
# 28                                   Carbonic anhydrase             Enzyme
# 29                                   Carbonic anhydrase             Enzyme
# ...                                                 ...                ...
# 4665                     Interleukin-1 receptor, type I  Membrane receptor
# 4666                     Interleukin-1 receptor, type I  Membrane receptor
# 4667  Granulocyte macrophage colony-stimulating fact...  Membrane receptor
# 4668  Granulocyte macrophage colony-stimulating fact...  Membrane receptor
# 4669                            Interleukin-11 receptor  Membrane receptor
# 4670                            Interleukin-11 receptor  Membrane receptor
# 4671                             Interleukin-2 receptor  Membrane receptor
# 4672                             Interleukin-2 receptor  Membrane receptor
# 4673                             Interleukin-2 receptor  Membrane receptor
# 4674                     Interferon alpha/beta receptor  Membrane receptor
# 4675                     Interferon alpha/beta receptor  Membrane receptor
# 4676                     Interferon alpha/beta receptor  Membrane receptor
# 4677                     Interferon alpha/beta receptor  Membrane receptor
# 4678                     Interferon alpha/beta receptor  Membrane receptor
# 4679                     Interferon alpha/beta receptor  Membrane receptor
# 4680                     Interferon alpha/beta receptor  Membrane receptor
# 4681                     Interferon alpha/beta receptor  Membrane receptor
# 4682                     Interferon alpha/beta receptor  Membrane receptor
# 4683                     Interferon alpha/beta receptor  Membrane receptor
# 4684                            Integrin alpha-L/beta-2           Adhesion
# 4685                            Integrin alpha-L/beta-2           Adhesion
# 4686                    T-cell surface glycoprotein CD3    Surface antigen
# 4687                    T-cell surface glycoprotein CD3    Surface antigen
# 4688                    T-cell surface glycoprotein CD3    Surface antigen
# 4689                            Interleukin-17 receptor  Membrane receptor
# 4690                            Interleukin-17 receptor  Membrane receptor
# 4691                                Phosphodiesterase 4             Enzyme
# 4692                                Phosphodiesterase 4             Enzyme
# 4693                                Phosphodiesterase 4             Enzyme
# 4694                                Phosphodiesterase 4             Enzyme
#
#                                               ACCESSION     GENE  \
# 0                                         Q01668|Q13936  CACNA1C
# 1                                         Q01668|Q13936  CACNA1D
# 2      O15399|O60391|Q05586|Q12879|Q13224|Q14957|Q8TCU5    GRIN1
# 3      O15399|O60391|Q05586|Q12879|Q13224|Q14957|Q8TCU5   GRIN2A
# 4      O15399|O60391|Q05586|Q12879|Q13224|Q14957|Q8TCU5   GRIN2B
# 5      O15399|O60391|Q05586|Q12879|Q13224|Q14957|Q8TCU5   GRIN2C
# 6      O15399|O60391|Q05586|Q12879|Q13224|Q14957|Q8TCU5   GRIN2D
# 7      O15399|O60391|Q05586|Q12879|Q13224|Q14957|Q8TCU5   GRIN3A
# 8      O15399|O60391|Q05586|Q12879|Q13224|Q14957|Q8TCU5   GRIN3B
# 9                                  P14867|P18507|P28472   GABRA1
# 10                                 P14867|P18507|P28472   GABRB3
# 11                                 P14867|P18507|P28472   GABRG2
# 12    O43570|P00915|P00918|P07451|P22748|P23280|P352...      CA1
# 13    O43570|P00915|P00918|P07451|P22748|P23280|P352...     CA12
# 14    O43570|P00915|P00918|P07451|P22748|P23280|P352...     CA13
# 15    O43570|P00915|P00918|P07451|P22748|P23280|P352...     CA14
# 16    O43570|P00915|P00918|P07451|P22748|P23280|P352...      CA2
# 17    O43570|P00915|P00918|P07451|P22748|P23280|P352...      CA3
# 18    O43570|P00915|P00918|P07451|P22748|P23280|P352...      CA4
# 19    O43570|P00915|P00918|P07451|P22748|P23280|P352...     CA5A
# 20    O43570|P00915|P00918|P07451|P22748|P23280|P352...     CA5B
# 21    O43570|P00915|P00918|P07451|P22748|P23280|P352...      CA6
# 22    O43570|P00915|P00918|P07451|P22748|P23280|P352...      CA7
# 23    O43570|P00915|P00918|P07451|P22748|P23280|P352...      CA9
# 24                                        P35218|Q9Y2D0     CA5A
# 25                                        P35218|Q9Y2D0     CA5B
# 26                          P00921|P18915|Q3SZX4|Q95323      CA2
# 27                          P00921|P18915|Q3SZX4|Q95323      CA3
# 28                          P00921|P18915|Q3SZX4|Q95323      CA4
# 29                          P00921|P18915|Q3SZX4|Q95323      CA6
# ...                                                 ...      ...
# 4665                                      P14778|Q9NPH3    IL1R1
# 4666                                      P14778|Q9NPH3   IL1RAP
# 4667                                      P15509|P32927   CSF2RA
# 4668                                      P15509|P32927   CSF2RB
# 4669                                      P40189|Q14626   IL11RA
# 4670                                      P40189|Q14626    IL6ST
# 4671                               P01589|P14784|P31785    IL2RA
# 4672                               P01589|P14784|P31785    IL2RB
# 4673                               P01589|P14784|P31785    IL2RG
# 4674                                      P17181|P48551   IFNAR1
# 4675                                      P17181|P48551   IFNAR2
# 4676                                      P17181|P48551   IFNAR1
# 4677                                      P17181|P48551   IFNAR2
# 4678                                      P17181|P48551   IFNAR1
# 4679                                      P17181|P48551   IFNAR2
# 4680                                      P17181|P48551   IFNAR1
# 4681                                      P17181|P48551   IFNAR2
# 4682                                      P17181|P48551   IFNAR1
# 4683                                      P17181|P48551   IFNAR2
# 4684                                      P05107|P20701    ITGAL
# 4685                                      P05107|P20701    ITGB2
# 4686                               P04234|P07766|P09693     CD3D
# 4687                               P04234|P07766|P09693     CD3E
# 4688                               P04234|P07766|P09693     CD3G
# 4689                                      Q8NAC3|Q96F46   IL17RA
# 4690                                      Q8NAC3|Q96F46   IL17RC
# 4691                        P27815|Q07343|Q08493|Q08499    PDE4A
# 4692                        P27815|Q07343|Q08493|Q08499    PDE4B
# 4693                        P27815|Q07343|Q08493|Q08499    PDE4C
# 4694                        P27815|Q07343|Q08493|Q08499    PDE4D
#
#                                               SWISSPROT  ACT_VALUE  ACT_UNIT  \
# 0                               CAC1C_HUMAN|CAC1D_HUMAN        NaN       NaN
# 1                               CAC1C_HUMAN|CAC1D_HUMAN        NaN       NaN
# 2     NMD3A_HUMAN|NMD3B_HUMAN|NMDE1_HUMAN|NMDE2_HUMA...        NaN       NaN
# 3     NMD3A_HUMAN|NMD3B_HUMAN|NMDE1_HUMAN|NMDE2_HUMA...        NaN       NaN
# 4     NMD3A_HUMAN|NMD3B_HUMAN|NMDE1_HUMAN|NMDE2_HUMA...        NaN       NaN
# 5     NMD3A_HUMAN|NMD3B_HUMAN|NMDE1_HUMAN|NMDE2_HUMA...        NaN       NaN
# 6     NMD3A_HUMAN|NMD3B_HUMAN|NMDE1_HUMAN|NMDE2_HUMA...        NaN       NaN
# 7     NMD3A_HUMAN|NMD3B_HUMAN|NMDE1_HUMAN|NMDE2_HUMA...        NaN       NaN
# 8     NMD3A_HUMAN|NMD3B_HUMAN|NMDE1_HUMAN|NMDE2_HUMA...        NaN       NaN
# 9                   GBRA1_HUMAN|GBRB3_HUMAN|GBRG2_HUMAN        NaN       NaN
# 10                  GBRA1_HUMAN|GBRB3_HUMAN|GBRG2_HUMAN        NaN       NaN
# 11                  GBRA1_HUMAN|GBRB3_HUMAN|GBRG2_HUMAN        NaN       NaN
# 12    CAH12_HUMAN|CAH13_HUMAN|CAH14_HUMAN|CAH1_HUMAN...   9.100000       NaN
# 13    CAH12_HUMAN|CAH13_HUMAN|CAH14_HUMAN|CAH1_HUMAN...   9.100000       NaN
# 14    CAH12_HUMAN|CAH13_HUMAN|CAH14_HUMAN|CAH1_HUMAN...   9.100000       NaN
# 15    CAH12_HUMAN|CAH13_HUMAN|CAH14_HUMAN|CAH1_HUMAN...   9.100000       NaN
# 16    CAH12_HUMAN|CAH13_HUMAN|CAH14_HUMAN|CAH1_HUMAN...   9.100000       NaN
# 17    CAH12_HUMAN|CAH13_HUMAN|CAH14_HUMAN|CAH1_HUMAN...   9.100000       NaN
# 18    CAH12_HUMAN|CAH13_HUMAN|CAH14_HUMAN|CAH1_HUMAN...   9.100000       NaN
# 19    CAH12_HUMAN|CAH13_HUMAN|CAH14_HUMAN|CAH1_HUMAN...   9.100000       NaN
# 20    CAH12_HUMAN|CAH13_HUMAN|CAH14_HUMAN|CAH1_HUMAN...   9.100000       NaN
# 21    CAH12_HUMAN|CAH13_HUMAN|CAH14_HUMAN|CAH1_HUMAN...   9.100000       NaN
# 22    CAH12_HUMAN|CAH13_HUMAN|CAH14_HUMAN|CAH1_HUMAN...   9.100000       NaN
# 23    CAH12_HUMAN|CAH13_HUMAN|CAH14_HUMAN|CAH1_HUMAN...   9.100000       NaN
# 24                              CAH5A_HUMAN|CAH5B_HUMAN   8.740000       NaN
# 25                              CAH5A_HUMAN|CAH5B_HUMAN   8.740000       NaN
# 26          CAH2_BOVIN|CAH3_BOVIN|CAH4_BOVIN|CAH6_BOVIN   7.800000       NaN
# 27          CAH2_BOVIN|CAH3_BOVIN|CAH4_BOVIN|CAH6_BOVIN   7.800000       NaN
# 28          CAH2_BOVIN|CAH3_BOVIN|CAH4_BOVIN|CAH6_BOVIN   7.800000       NaN
# 29          CAH2_BOVIN|CAH3_BOVIN|CAH4_BOVIN|CAH6_BOVIN   7.800000       NaN
# ...                                                 ...        ...       ...
# 4665                            IL1AP_HUMAN|IL1R1_HUMAN   7.820000       NaN
# 4666                            IL1AP_HUMAN|IL1R1_HUMAN   7.820000       NaN
# 4667                            CSF2R_HUMAN|IL3RB_HUMAN   8.301030       NaN
# 4668                            CSF2R_HUMAN|IL3RB_HUMAN   8.301030       NaN
# 4669                            I11RA_HUMAN|IL6RB_HUMAN        NaN       NaN
# 4670                            I11RA_HUMAN|IL6RB_HUMAN        NaN       NaN
# 4671                IL2RA_HUMAN|IL2RB_HUMAN|IL2RG_HUMAN        NaN       NaN
# 4672                IL2RA_HUMAN|IL2RB_HUMAN|IL2RG_HUMAN        NaN       NaN
# 4673                IL2RA_HUMAN|IL2RB_HUMAN|IL2RG_HUMAN        NaN       NaN
# 4674                            INAR1_HUMAN|INAR2_HUMAN        NaN       NaN
# 4675                            INAR1_HUMAN|INAR2_HUMAN        NaN       NaN
# 4676                            INAR1_HUMAN|INAR2_HUMAN        NaN       NaN
# 4677                            INAR1_HUMAN|INAR2_HUMAN        NaN       NaN
# 4678                            INAR1_HUMAN|INAR2_HUMAN        NaN       NaN
# 4679                            INAR1_HUMAN|INAR2_HUMAN        NaN       NaN
# 4680                            INAR1_HUMAN|INAR2_HUMAN        NaN       NaN
# 4681                            INAR1_HUMAN|INAR2_HUMAN        NaN       NaN
# 4682                            INAR1_HUMAN|INAR2_HUMAN        NaN       NaN
# 4683                            INAR1_HUMAN|INAR2_HUMAN        NaN       NaN
# 4684                              ITAL_HUMAN|ITB2_HUMAN   8.045757       NaN
# 4685                              ITAL_HUMAN|ITB2_HUMAN   8.045757       NaN
# 4686                   CD3D_HUMAN|CD3E_HUMAN|CD3G_HUMAN        NaN       NaN
# 4687                   CD3D_HUMAN|CD3E_HUMAN|CD3G_HUMAN        NaN       NaN
# 4688                   CD3D_HUMAN|CD3E_HUMAN|CD3G_HUMAN        NaN       NaN
# 4689                            I17RA_HUMAN|I17RC_HUMAN   9.200000       NaN
# 4690                            I17RA_HUMAN|I17RC_HUMAN   9.200000       NaN
# 4691    PDE4A_HUMAN|PDE4B_HUMAN|PDE4C_HUMAN|PDE4D_HUMAN   6.309804       NaN
# 4692    PDE4A_HUMAN|PDE4B_HUMAN|PDE4C_HUMAN|PDE4D_HUMAN   6.309804       NaN
# 4693    PDE4A_HUMAN|PDE4B_HUMAN|PDE4C_HUMAN|PDE4D_HUMAN   6.309804       NaN
# 4694    PDE4A_HUMAN|PDE4B_HUMAN|PDE4C_HUMAN|PDE4D_HUMAN   6.309804       NaN
#
#      ACT_TYPE                                        ACT_COMMENT  \
# 0         NaN                                Mechanism of Action
# 1         NaN                                Mechanism of Action
# 2         NaN  Mechanism of Action; CHEMBL2094124; PROTEIN CO...
# 3         NaN  Mechanism of Action; CHEMBL2094124; PROTEIN CO...
# 4         NaN  Mechanism of Action; CHEMBL2094124; PROTEIN CO...
# 5         NaN  Mechanism of Action; CHEMBL2094124; PROTEIN CO...
# 6         NaN  Mechanism of Action; CHEMBL2094124; PROTEIN CO...
# 7         NaN  Mechanism of Action; CHEMBL2094124; PROTEIN CO...
# 8         NaN  Mechanism of Action; CHEMBL2094124; PROTEIN CO...
# 9         NaN                                                NaN
# 10        NaN                                                NaN
# 11        NaN                                                NaN
# 12         Ki  Compound was evaluated for the inhibition of C...
# 13         Ki  Compound was evaluated for the inhibition of C...
# 14         Ki  Compound was evaluated for the inhibition of C...
# 15         Ki  Compound was evaluated for the inhibition of C...
# 16         Ki  Compound was evaluated for the inhibition of C...
# 17         Ki  Compound was evaluated for the inhibition of C...
# 18         Ki  Compound was evaluated for the inhibition of C...
# 19         Ki  Compound was evaluated for the inhibition of C...
# 20         Ki  Compound was evaluated for the inhibition of C...
# 21         Ki  Compound was evaluated for the inhibition of C...
# 22         Ki  Compound was evaluated for the inhibition of C...
# 23         Ki  Compound was evaluated for the inhibition of C...
# 24         Ki  Mean inhibitory constant towards human carboni...
# 25         Ki  Mean inhibitory constant towards human carboni...
# 26       IC50  In vitro concentration that causes 50% inhibit...
# 27       IC50  In vitro concentration that causes 50% inhibit...
# 28       IC50  In vitro concentration that causes 50% inhibit...
# 29       IC50  In vitro concentration that causes 50% inhibit...
# ...       ...                                                ...
# 4665       Kd                                Mechanism of Action
# 4666       Kd                                Mechanism of Action
# 4667       Kd                                Mechanism of Action
# 4668       Kd                                Mechanism of Action
# 4669      NaN                                Mechanism of Action
# 4670      NaN                                Mechanism of Action
# 4671      NaN                                Mechanism of Action
# 4672      NaN                                Mechanism of Action
# 4673      NaN                                Mechanism of Action
# 4674      NaN                                Mechanism of Action
# 4675      NaN                                Mechanism of Action
# 4676      NaN                                Mechanism of Action
# 4677      NaN                                Mechanism of Action
# 4678      NaN                                Mechanism of Action
# 4679      NaN                                Mechanism of Action
# 4680      NaN                                Mechanism of Action
# 4681      NaN                                Mechanism of Action
# 4682      NaN                                Mechanism of Action
# 4683      NaN                                Mechanism of Action
# 4684     IC50  inhibition of ICAM-1 binding to LFA-1 in HuT 7...
# 4685     IC50  inhibition of ICAM-1 binding to LFA-1 in HuT 7...
# 4686      NaN                                Mechanism of Action
# 4687      NaN                                Mechanism of Action
# 4688      NaN                                Mechanism of Action
# 4689       Kd                                                NaN
# 4690       Kd                                                NaN
# 4691     IC50                                                NaN
# 4692     IC50                                                NaN
# 4693     IC50                                                NaN
# 4694     IC50                                                NaN
#
#                  ACT_SOURCE RELATION  MOA             MOA_SOURCE  \
# 0                DRUG LABEL      NaN  1.0             DRUG LABEL
# 1                DRUG LABEL      NaN  1.0             DRUG LABEL
# 2                    CHEMBL      NaN  1.0                 CHEMBL
# 3                    CHEMBL      NaN  1.0                 CHEMBL
# 4                    CHEMBL      NaN  1.0                 CHEMBL
# 5                    CHEMBL      NaN  1.0                 CHEMBL
# 6                    CHEMBL      NaN  1.0                 CHEMBL
# 7                    CHEMBL      NaN  1.0                 CHEMBL
# 8                    CHEMBL      NaN  1.0                 CHEMBL
# 9                 WOMBAT-PK      NaN  1.0                 CHEMBL
# 10                WOMBAT-PK      NaN  1.0                 CHEMBL
# 11                WOMBAT-PK      NaN  1.0                 CHEMBL
# 12                   CHEMBL        =  NaN                    NaN
# 13                   CHEMBL        =  NaN                    NaN
# 14                   CHEMBL        =  NaN                    NaN
# 15                   CHEMBL        =  NaN                    NaN
# 16                   CHEMBL        =  NaN                    NaN
# 17                   CHEMBL        =  NaN                    NaN
# 18                   CHEMBL        =  NaN                    NaN
# 19                   CHEMBL        =  NaN                    NaN
# 20                   CHEMBL        =  NaN                    NaN
# 21                   CHEMBL        =  NaN                    NaN
# 22                   CHEMBL        =  NaN                    NaN
# 23                   CHEMBL        =  NaN                    NaN
# 24                   CHEMBL        =  NaN                    NaN
# 25                   CHEMBL        =  NaN                    NaN
# 26                   CHEMBL        =  NaN                    NaN
# 27                   CHEMBL        =  NaN                    NaN
# 28                   CHEMBL        =  NaN                    NaN
# 29                   CHEMBL        =  NaN                    NaN
# ...                     ...      ...  ...                    ...
# 4665                 IUPHAR        =  1.0             DRUG LABEL
# 4666                 IUPHAR        =  1.0             DRUG LABEL
# 4667  SCIENTIFIC LITERATURE        =  1.0  SCIENTIFIC LITERATURE
# 4668  SCIENTIFIC LITERATURE        =  1.0  SCIENTIFIC LITERATURE
# 4669             DRUG LABEL      NaN  1.0             DRUG LABEL
# 4670             DRUG LABEL      NaN  1.0             DRUG LABEL
# 4671             DRUG LABEL      NaN  1.0             DRUG LABEL
# 4672             DRUG LABEL      NaN  1.0             DRUG LABEL
# 4673             DRUG LABEL      NaN  1.0             DRUG LABEL
# 4674             DRUG LABEL      NaN  1.0             DRUG LABEL
# 4675             DRUG LABEL      NaN  1.0             DRUG LABEL
# 4676             DRUG LABEL      NaN  1.0             DRUG LABEL
# 4677             DRUG LABEL      NaN  1.0             DRUG LABEL
# 4678             DRUG LABEL      NaN  1.0             DRUG LABEL
# 4679             DRUG LABEL      NaN  1.0             DRUG LABEL
# 4680             DRUG LABEL      NaN  1.0             DRUG LABEL
# 4681             DRUG LABEL      NaN  1.0             DRUG LABEL
# 4682             DRUG LABEL      NaN  1.0             DRUG LABEL
# 4683             DRUG LABEL      NaN  1.0             DRUG LABEL
# 4684  SCIENTIFIC LITERATURE        =  1.0             DRUG LABEL
# 4685  SCIENTIFIC LITERATURE        =  1.0             DRUG LABEL
# 4686                 IUPHAR      NaN  1.0                 IUPHAR
# 4687                 IUPHAR      NaN  1.0                 IUPHAR
# 4688                 IUPHAR      NaN  1.0                 IUPHAR
# 4689                 IUPHAR        =  1.0  SCIENTIFIC LITERATURE
# 4690                 IUPHAR        =  1.0  SCIENTIFIC LITERATURE
# 4691  SCIENTIFIC LITERATURE        =  1.0             DRUG LABEL
# 4692  SCIENTIFIC LITERATURE        =  1.0             DRUG LABEL
# 4693  SCIENTIFIC LITERATURE        =  1.0             DRUG LABEL
# 4694  SCIENTIFIC LITERATURE        =  1.0             DRUG LABEL
#
#                                          ACT_SOURCE_URL  \
# 0     http://www.accessdata.fda.gov/drugsatfda_docs/...
# 1     http://www.accessdata.fda.gov/drugsatfda_docs/...
# 2     https://www.ebi.ac.uk/chembl/compound/inspect/...
# 3     https://www.ebi.ac.uk/chembl/compound/inspect/...
# 4     https://www.ebi.ac.uk/chembl/compound/inspect/...
# 5     https://www.ebi.ac.uk/chembl/compound/inspect/...
# 6     https://www.ebi.ac.uk/chembl/compound/inspect/...
# 7     https://www.ebi.ac.uk/chembl/compound/inspect/...
# 8     https://www.ebi.ac.uk/chembl/compound/inspect/...
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12    https://www.ebi.ac.uk/chembl/compound/inspect/...
# 13    https://www.ebi.ac.uk/chembl/compound/inspect/...
# 14    https://www.ebi.ac.uk/chembl/compound/inspect/...
# 15    https://www.ebi.ac.uk/chembl/compound/inspect/...
# 16    https://www.ebi.ac.uk/chembl/compound/inspect/...
# 17    https://www.ebi.ac.uk/chembl/compound/inspect/...
# 18    https://www.ebi.ac.uk/chembl/compound/inspect/...
# 19    https://www.ebi.ac.uk/chembl/compound/inspect/...
# 20    https://www.ebi.ac.uk/chembl/compound/inspect/...
# 21    https://www.ebi.ac.uk/chembl/compound/inspect/...
# 22    https://www.ebi.ac.uk/chembl/compound/inspect/...
# 23    https://www.ebi.ac.uk/chembl/compound/inspect/...
# 24    https://www.ebi.ac.uk/chembl/compound/inspect/...
# 25    https://www.ebi.ac.uk/chembl/compound/inspect/...
# 26    https://www.ebi.ac.uk/chembl/compound/inspect/...
# 27    https://www.ebi.ac.uk/chembl/compound/inspect/...
# 28    https://www.ebi.ac.uk/chembl/compound/inspect/...
# 29    https://www.ebi.ac.uk/chembl/compound/inspect/...
# ...                                                 ...
# 4665  http://www.guidetopharmacology.org/GRAC/Ligand...
# 4666  http://www.guidetopharmacology.org/GRAC/Ligand...
# 4667         http://www.ncbi.nlm.nih.gov/pubmed/2001448
# 4668         http://www.ncbi.nlm.nih.gov/pubmed/2001448
# 4669  http://www.accessdata.fda.gov/drugsatfda_docs/...
# 4670  http://www.accessdata.fda.gov/drugsatfda_docs/...
# 4671                                                NaN
# 4672                                                NaN
# 4673                                                NaN
# 4674                                                NaN
# 4675                                                NaN
# 4676                                                NaN
# 4677                                                NaN
# 4678                                                NaN
# 4679                                                NaN
# 4680                                                NaN
# 4681                                                NaN
# 4682                                                NaN
# 4683                                                NaN
# 4684        http://www.ncbi.nlm.nih.gov/pubmed/24900456
# 4685        http://www.ncbi.nlm.nih.gov/pubmed/24900456
# 4686  http://www.guidetopharmacology.org/GRAC/Ligand...
# 4687  http://www.guidetopharmacology.org/GRAC/Ligand...
# 4688  http://www.guidetopharmacology.org/GRAC/Ligand...
# 4689  http://www.guidetopharmacology.org/GRAC/Ligand...
# 4690  http://www.guidetopharmacology.org/GRAC/Ligand...
# 4691        http://www.ncbi.nlm.nih.gov/pubmed/20188549
# 4692        http://www.ncbi.nlm.nih.gov/pubmed/20188549
# 4693        http://www.ncbi.nlm.nih.gov/pubmed/20188549
# 4694        http://www.ncbi.nlm.nih.gov/pubmed/20188549
#
#                                          MOA_SOURCE_URL         ACTION_TYPE  \
# 0     http://www.accessdata.fda.gov/drugsatfda_docs/...             BLOCKER
# 1     http://www.accessdata.fda.gov/drugsatfda_docs/...             BLOCKER
# 2     https://www.ebi.ac.uk/chembl/compound/inspect/...          ANTAGONIST
# 3     https://www.ebi.ac.uk/chembl/compound/inspect/...          ANTAGONIST
# 4     https://www.ebi.ac.uk/chembl/compound/inspect/...          ANTAGONIST
# 5     https://www.ebi.ac.uk/chembl/compound/inspect/...          ANTAGONIST
# 6     https://www.ebi.ac.uk/chembl/compound/inspect/...          ANTAGONIST
# 7     https://www.ebi.ac.uk/chembl/compound/inspect/...          ANTAGONIST
# 8     https://www.ebi.ac.uk/chembl/compound/inspect/...          ANTAGONIST
# 9     https://www.ebi.ac.uk/chembl/compound/inspect/...  POSITIVE MODULATOR
# 10    https://www.ebi.ac.uk/chembl/compound/inspect/...  POSITIVE MODULATOR
# 11    https://www.ebi.ac.uk/chembl/compound/inspect/...  POSITIVE MODULATOR
# 12                                                  NaN                 NaN
# 13                                                  NaN                 NaN
# 14                                                  NaN                 NaN
# 15                                                  NaN                 NaN
# 16                                                  NaN                 NaN
# 17                                                  NaN                 NaN
# 18                                                  NaN                 NaN
# 19                                                  NaN                 NaN
# 20                                                  NaN                 NaN
# 21                                                  NaN                 NaN
# 22                                                  NaN                 NaN
# 23                                                  NaN                 NaN
# 24                                                  NaN                 NaN
# 25                                                  NaN                 NaN
# 26                                                  NaN                 NaN
# 27                                                  NaN                 NaN
# 28                                                  NaN                 NaN
# 29                                                  NaN                 NaN
# ...                                                 ...                 ...
# 4665  http://www.accessdata.fda.gov/drugsatfda_docs/...          ANTAGONIST
# 4666  http://www.accessdata.fda.gov/drugsatfda_docs/...          ANTAGONIST
# 4667         http://www.ncbi.nlm.nih.gov/pubmed/2001448             AGONIST
# 4668         http://www.ncbi.nlm.nih.gov/pubmed/2001448             AGONIST
# 4669  http://www.accessdata.fda.gov/drugsatfda_docs/...             AGONIST
# 4670  http://www.accessdata.fda.gov/drugsatfda_docs/...             AGONIST
# 4671  http://www.accessdata.fda.gov/drugsatfda_docs/...    ANTIBODY BINDING
# 4672  http://www.accessdata.fda.gov/drugsatfda_docs/...    ANTIBODY BINDING
# 4673  http://www.accessdata.fda.gov/drugsatfda_docs/...    ANTIBODY BINDING
# 4674  http://www.accessdata.fda.gov/drugsatfda_docs/...             AGONIST
# 4675  http://www.accessdata.fda.gov/drugsatfda_docs/...             AGONIST
# 4676  http://www.accessdata.fda.gov/drugsatfda_docs/...             AGONIST
# 4677  http://www.accessdata.fda.gov/drugsatfda_docs/...             AGONIST
# 4678  http://www.accessdata.fda.gov/drugsatfda_docs/...             AGONIST
# 4679  http://www.accessdata.fda.gov/drugsatfda_docs/...             AGONIST
# 4680  http://www.accessdata.fda.gov/drugsatfda_docs/...             AGONIST
# 4681  http://www.accessdata.fda.gov/drugsatfda_docs/...             AGONIST
# 4682  http://www.accessdata.fda.gov/drugsatfda_docs/...             AGONIST
# 4683  http://www.accessdata.fda.gov/drugsatfda_docs/...             AGONIST
# 4684  http://www.accessdata.fda.gov/drugsatfda_docs/...          ANTAGONIST
# 4685  http://www.accessdata.fda.gov/drugsatfda_docs/...          ANTAGONIST
# 4686  http://www.guidetopharmacology.org/GRAC/Ligand...    ANTIBODY BINDING
# 4687  http://www.guidetopharmacology.org/GRAC/Ligand...    ANTIBODY BINDING
# 4688  http://www.guidetopharmacology.org/GRAC/Ligand...    ANTIBODY BINDING
# 4689        http://www.ncbi.nlm.nih.gov/pubmed/22455412    ANTIBODY BINDING
# 4690        http://www.ncbi.nlm.nih.gov/pubmed/22455412    ANTIBODY BINDING
# 4691  http://www.accessdata.fda.gov/drugsatfda_docs/...           INHIBITOR
# 4692  http://www.accessdata.fda.gov/drugsatfda_docs/...           INHIBITOR
# 4693  http://www.accessdata.fda.gov/drugsatfda_docs/...           INHIBITOR
# 4694  http://www.accessdata.fda.gov/drugsatfda_docs/...           INHIBITOR
#
#                                                     TDL      ORGANISM
# 0                                           Tclin|Tclin  Homo sapiens
# 1                                           Tclin|Tclin  Homo sapiens
# 2             Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin  Homo sapiens
# 3             Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin  Homo sapiens
# 4             Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin  Homo sapiens
# 5             Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin  Homo sapiens
# 6             Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin  Homo sapiens
# 7             Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin  Homo sapiens
# 8             Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin  Homo sapiens
# 9                                     Tclin|Tclin|Tclin  Homo sapiens
# 10                                    Tclin|Tclin|Tclin  Homo sapiens
# 11                                    Tclin|Tclin|Tclin  Homo sapiens
# 12    Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tcli...  Homo sapiens
# 13    Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tcli...  Homo sapiens
# 14    Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tcli...  Homo sapiens
# 15    Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tcli...  Homo sapiens
# 16    Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tcli...  Homo sapiens
# 17    Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tcli...  Homo sapiens
# 18    Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tcli...  Homo sapiens
# 19    Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tcli...  Homo sapiens
# 20    Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tcli...  Homo sapiens
# 21    Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tcli...  Homo sapiens
# 22    Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tcli...  Homo sapiens
# 23    Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tclin|Tcli...  Homo sapiens
# 24                                          Tclin|Tclin  Homo sapiens
# 25                                          Tclin|Tclin  Homo sapiens
# 26                                                  NaN    Bos taurus
# 27                                                  NaN    Bos taurus
# 28                                                  NaN    Bos taurus
# 29                                                  NaN    Bos taurus
# ...                                                 ...           ...
# 4665                                        Tclin|Tclin  Homo sapiens
# 4666                                        Tclin|Tclin  Homo sapiens
# 4667                                        Tclin|Tclin  Homo sapiens
# 4668                                        Tclin|Tclin  Homo sapiens
# 4669                                        Tclin|Tclin  Homo sapiens
# 4670                                        Tclin|Tclin  Homo sapiens
# 4671                                  Tclin|Tclin|Tclin  Homo sapiens
# 4672                                  Tclin|Tclin|Tclin  Homo sapiens
# 4673                                  Tclin|Tclin|Tclin  Homo sapiens
# 4674                                        Tclin|Tclin  Homo sapiens
# 4675                                        Tclin|Tclin  Homo sapiens
# 4676                                        Tclin|Tclin  Homo sapiens
# 4677                                        Tclin|Tclin  Homo sapiens
# 4678                                        Tclin|Tclin  Homo sapiens
# 4679                                        Tclin|Tclin  Homo sapiens
# 4680                                        Tclin|Tclin  Homo sapiens
# 4681                                        Tclin|Tclin  Homo sapiens
# 4682                                        Tclin|Tclin  Homo sapiens
# 4683                                        Tclin|Tclin  Homo sapiens
# 4684                                        Tclin|Tclin  Homo sapiens
# 4685                                        Tclin|Tclin  Homo sapiens
# 4686                                  Tclin|Tclin|Tclin  Homo sapiens
# 4687                                  Tclin|Tclin|Tclin  Homo sapiens
# 4688                                  Tclin|Tclin|Tclin  Homo sapiens
# 4689                                        Tclin|Tclin  Homo sapiens
# 4690                                        Tclin|Tclin  Homo sapiens
# 4691                            Tclin|Tclin|Tclin|Tclin  Homo sapiens
# 4692                            Tclin|Tclin|Tclin|Tclin  Homo sapiens
# 4693                            Tclin|Tclin|Tclin|Tclin  Homo sapiens
# 4694                            Tclin|Tclin|Tclin|Tclin  Homo sapiens
#
# [4695 rows x 20 columns]
