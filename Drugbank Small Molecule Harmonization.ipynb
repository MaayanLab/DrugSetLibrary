# %% [markdown]
# ## Drugbank Small Molecules Harmonization
# #### ALL DATABASES ACCESSED 05/01/19
# ##### Author : Eryk Kropiwnicki | eryk.kropiwnicki@icahn.mssm.edu

# %%
import csv
import pubchempy as pcp
import time 
import requests
import json
from collections import defaultdict
import pandas as pd
import numpy as np

# %%
smallmolecules = []

db_drugs = open('input/drug links-3.csv')
db_drugs_csv = csv.reader(db_drugs)
for row in db_drugs_csv:
    smallmolecules.append(row[1].lower())
del smallmolecules[0]

# %%
len(smallmolecules)
# Out:
# 10254

# %% [markdown]
# ### VERIFY ALL COLLECTED DRUGS BY ASSOCIATION WITH ATTRIBUTES
# #### DATABASE FOR Synonyms, Pubchem IDs, SMILEs Strings, InChiKeys, and Molecular Formulas: https://pubchem.ncbi.nlm.nih.gov
# #### DATABASE FOR DRUGBANK ACCESSION NUMBERS: http://www.drugbank.ca
# #### OUTPUT FILE: drugbank_smallmolecules_attributes.csv

# %%
# Retrieve all synonyms associated with each drug name #
failed = 0
synonym_dict = {}

for drug in smallmolecules:
    url = 'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/'+str(drug)+ '/synonyms/JSON'
    response = requests.get(url)
    try:
        response.json()
    except ValueError:
        continue
    if 'InformationList' in response.json().keys():
        synonym = response.json()['InformationList']['Information'][0]['Synonym']
        synonym = [x.lower() for x in synonym]
        synonym_dict[drug] = synonym
    else:
        failed += 1
    time.sleep(1)

# %%
synonym_dict
# Out:
# {'bivalirudin': ['bivalirudin',
#   '128270-60-0',
#   'angiomax',
#   'hirulog',
#   'bivalirudina',
#   'bivalirudinum',
#   'bivalirudin trifluoroacetate',
#   'bg-8967',
#   'unii-tn9bex005g',
#   'bg8967',
#   'bivalirudin trifluoacetate',
#   'tn9bex005g',
#   'd-phenylalanyl-l-prolyl-l-arginyl-l-prolylglycylglycylglycylglycyl-l-asparaginylglycyl-l-alpha-aspartyl-l-phenylalanyl-l-alpha-glutamyl-l-alpha-glutamyl-l-isoleucyl-l-prolyl-l-alpha-glutamyl-l-alpha-glutamyl-l-tyrosyl-l-leucine',
#   'chebi:59173',
#   'hirulog-1',
#   'l-leucine, d-phenylalanyl-l-prolyl-l-arginyl-l-prolylglycylglycylglycylglycyl-l-asparaginylglycyl-l-alpha-aspartyl-l-phenylalanyl-l-alpha-glutamyl-l-alpha-glutamyl-l-isoleucyl-l-prolyl-l-alpha-glutamyl-l-alpha-glutamyl-l-tyrosyl-',
#   'angiox',
#   'bivalirudine',
#   'bg 8967',
#   'bivalirudin [usan:ban:inn]',
#   'bivalirudin [usan:inn:ban]',
#   'phe-pro-arg-pro-(gly)4-desulfohirudin-(53-64)',
#   "phe-pro-arg-pro-(gly)4 desulfato-tyr63'-hirugen",
#   'c98h138n24o33',
#   'hs-2004',
#   'phe-pro-arg-pro-(gly)4-asn-gly-asp-phe-glu-glu-ile-pro-glu-glu-tyr-leu',
#   'schembl25739',
#   'gtpl6470',
#   'c9h11no.c2h6.ch4',
#   'chembl2103749',
#   'ks-00002wun',
#   'bivalirudin;0.9% sodium chloride',
#   '1191386-55-6',
#   'ebd32115',
#   'akos015994644',
#   'an-7543',
#   'db00006',
#   'bc657176',
#   'ls-172701',
#   '70b600',
#   '270b600',
#   'j-005587',
#   '(r,r)-2,6-bis(4,5-dihydro-4-phenyl-2-oxazolyl)pyridine; (r,r)-2,6-bis(4-phenyl-2-oxazolinyl)pyridine; (+)-2,6-bis[(4r)-4-phenyl-2-oxazolin-2-yl]pyridine'],
#  'goserelin': ['goserelin',
#   'goserelin acetate',
#   'zoladex',
#   '65807-02-5',
#   'decapeptide i',
#   'ici 118630',
#   'unii-0f65r8p09n',
#   '145781-92-6',
#   'ici-118630',
#   '0f65r8p09n',
#   'fertilan',
#   'gosereline [french]',
#   'goserelinum [latin]',
#   'goserelina [spanish]',
#   'goserelin [usan:inn:ban]',
#   'goserelina',
#   'gosereline',
#   'goserelinum',
#   'd-ser(t-bu)(sup 6)aza-gly(sup 10)-gnrh',
#   '[d-ser(tbu)6,azagly10]-lhrh acetate salt',
#   'hsdb 7606',
#   'fertilan deuterated',
#   '1-(5-oxo-l-prolyl-l-histidyl-l-tryptophyl-l-seryl-l-tyrosyl-o-tert-butyl-d-seryl-l-leucyl-l-arginyl-l-prolyl)semicarbazide',
#   'luteinizing hormone-releasing factor (pig), 6-(o-(1,1-dimethylethyl)-d-serine)-10-deglycinamide-, 2-(aminocarbonyl)hydrazide',
#   '4-d-ser-goserelin',
#   'hs-2015',
#   'zd-9393',
#   'goserelin (usan/inn)',
#   'ac1nsk1t',
#   'schembl8643',
#   'goserelin deuterated acetate',
#   'd-ser(but)6azgly10lhrh',
#   'chebi:5523',
#   'gtpl3879',
#   'chembl1201247',
#   'dtxsid7048297',
#   'schembl19712239',
#   'schembl20459194',
#   'ks-00002wus',
#   'd-ser(but)6azgly10-gonadorelin',
#   'hms2089d16',
#   'mfcd01747329',
#   'akos015994653',
#   'akos030213245',
#   'cs-3114',
#   'db00014',
#   'ici 118,630',
#   'hy-13673',
#   'd-ser(but)6azgly10-gonadorelin deuterated',
#   'b3723',
#   '81g926',
#   'd04405',
#   'ab01275466-01',
#   '807g025',
#   '6-[o-(1,1-dimethylethyl)-d-serine]-1-9-luteinizing hormone-releasing factor (swine) 2-(aminocarbonyl)hydrazide acetate',
#   '6-[o-(1,1-dimethylethyl)-d-serine]-1-9-luteinizing hormone-releasing factor (swine) 2-(aminocarbonyl)hydrazide acetate deuterated',
#   '70280-59-0'],
#  'desmopressin': ['desmopressin',
#   '16679-58-6',
#   'desmopresina',
#   'desmopressine',
#   'unii-enr1llb0fp',
#   '1-deamino-8-d-arginine vasopressin',
#   'desmopressinum',
#   'ddavp',
#   'enr1llb0fp',
#   'chembl1429',
#   'chebi:4450',
#   'desmopressin acetate',
#   '1-desamino-8-d-arginine vasopressin',
#   'desmopressin [inn:ban]',
#   'deamino arginine vasopressin',
#   'desmopresina [inn-spanish]',
#   'desmopressine [inn-french]',
#   'desmopressinum [inn-latin]',
#   '1-(3-mercaptopropionic acid)-8-d-arginine-vasopressin',
#   'einecs 240-726-7',
#   'desamino-8-d-arginine vasopressin, l-',
#   'deamino-8-d-arginine, l-, vasopressin',
#   '1-{[(4r,7s,10s,13s,16s)-7-(2-amino-2-oxoethyl)-10-(3-amino-3-oxopropyl)-13-benzyl-16-(4-hydroxybenzyl)-6,9,12,15,18-pentaoxo-1,2-dithia-5,8,11,14,17-pentaazacycloicosan-4-yl]carbonyl}-l-prolyl-d-arginylglycinamide',
#   'vasopressin, 1-(3-mercaptopropanoic acid)-8-d-arginine-',
#   'desmopressin-acetate',
#   'c46h64n14o12s2',
#   'ac1nsjxn',
#   'schembl14027607',
#   'ks-00002wuq',
#   '62288-83-9 (monoacetate)',
#   'nflwumrgjytjin-pnioqbsnsa-n',
#   '(deamino-cys1,d-arg8)-vasopressin',
#   '3576ah',
#   'bdbm50205308',
#   'cd-644',
#   'akos015994650',
#   'hs-2010',
#   '62357-86-2 (monoacetate trihydrate)',
#   'sc-18848',
#   'ft-0688024',
#   'w-5074',
#   '679d586',
#   '(2s)-n-[(2r)-1-[(2-amino-2-oxoethyl)amino]-5-(diaminomethylideneamino)-1-oxopentan-2-yl]-1-[(4r,7s,10s,13s,16s)-7-(2-amino-2-oxoethyl)-10-(3-amino-3-oxopropyl)-13-benzyl-16-[(4-hydroxyphenyl)methyl]-6,9,12,15,18-pentaoxo-1,2-dithia-5,8,11,14,17-pentazacycloicosane-4-carbonyl]pyrrolidine-2-carboxamide',
#   '(s)-1-((4r,7s,10s,13s,16s)-7-(2-amino-2-oxoethyl)-10-(3-amino-3-oxopropyl)-13-benzyl-16-(4-hydroxybenzyl)-6,9,12,15,18-pentaoxo-1,2-dithia-5,8,11,14,17-pentaazacycloicosane-4-carbonyl)-n-((r)-1-(2-amino-2-oxoethylamino)-5-guanidino-1-oxopentan-2-yl)pyrrolidine-2-carboxamide'],
#  'cetrorelix': ['cetrorelix',
#   '120287-85-6',
#   'cetrorelix acetate',
#   'cetrorelixum',
#   'cetrotide',
#   'unii-oon1hfz4ba',
#   'cetrelix acetate',
#   'sb 75',
#   'cetrorelixum [inn-latin]',
#   'oon1hfz4ba',
#   'cetrotide (tn)',
#   'chebi:59224',
#   '130143-01-0',
#   'cetrorelix (inn)',
#   'cetrorelix acetate(cetrotide)/',
#   'sb-075',
#   'cetrorelix [inn:ban]',
#   'c70h92cln17o14',
#   'hsdb 7696',
#   'hs-2008',
#   'schembl61331',
#   'cetrorelix(cetrorelix acetate)',
#   'gtpl1190',
#   'chembl1200490',
#   'dtxsid7040996',
#   'schembl19712202',
#   'ks-00002wup',
#   'n-acetyl-3-(2-naphthyl)-d-alanyl-p-chloro-d-phenylalanyl-3-(3-pyridyl)-d-alanyl-l-seryl-l-tyrosyl-n(sup 5)-carbamoyl-d-ornithyl-l-leucyl-l-arginyl-l-prolyl-d-alaninamide',
#   'abp000574',
#   'bdbm50369965',
#   'ac-d-nal(2)-d-phe(pcl)-d-pal(3)-ser-tyr-d-cit-leu-arg-pro-d-ala-nh2',
#   'akos015994648',
#   'db00050',
#   'ncgc00485296-01',
#   'ac-28734',
#   'n-acetyl-3-(2-naphthyl)-d-alanyl-4-chloro-d-phenylalanyl-3-(3-pyridyl)-d-alanyl-l-seryl-l-tyrosyl-n5-carbomoyl-d-ornithyl-l-leucyl-l-prolyl-d-alaninamide',
#   'n-acetyl-3-(naphthalen-2-yl)-d-alanyl-4-chloro-d-phenylalanyl-3-(pyridin-3-yl)-d-alanyl-l-seryl-l-tyrosyl-n(5)-carbamoyl-d-ornithyl-l-leucyl-l-arginyl-l-prolyl-d-alaninamide',
#   'sc-50568',
#   'sc-82639',
#   'ft-0647968',
#   'ft-0656251',
#   'v0412',
#   'd07665',
#   '287c856',
#   'c-35500',
#   'y-100040',
#   '(s)-1-(((r)-2-((s)-2-((s)-2-((r)-2-((r)-2-((r)-2-acetamido-3-(naphthalen-2-yl)propanamido)-3-(4-chlorophenyl)propanamido)-3-(pyridin-3-yl)propanamido)-3-hydroxypropanamido)-3-(4-hyd',
#   'ac-(d-ala[3-(2-naphthyl)])-[d-phe(4-cl)]-(d-ala[3-(3-pyridyl)])-ser-tyr-(d-cit)-leu-arg-pro-d-ala-oh',
#   'roxyphenyl)propanamido)-5-ureidopentanoyl)-l-leucyl-l-arginyl)-n-((r)-1-amino-1-oxopropan-2-yl)pyrrolidine-2-carboxamide'],
#  'daptomycin': ['daptomycin',
#   '103060-53-3',
#   'cubicin',
#   'cidecin',
#   'daptomicina',
#   'daptomycine',
#   'daptomycinum',
#   'chebi:600103',
#   'dapcin',
#   'c72h101n17o26',
#   'ly146032',
#   'n-decanoyl-l-tryptophyl-l-asparaginyl-n-[(3s,6s,9r,15s,18r,21s,24s,30s,31r)-3-[2-(2-aminophenyl)-2-oxoethyl]-24-(3-aminopropyl)-15,21-bis(carboxymethyl)-6-[(2r)-1-carboxypropan-2-yl]-9-(hydroxymethyl)-18,31-dimethyl-2,5,8,11,14,17,20,23,26,29-decaoxo-1-oxa-4,7,10,13,16,19,22,25,28-nonaazacyclohentriacontan-30-yl]-l-alpha-asparagine',
#   'ly-146032',
#   'ly 146032',
#   'schembl28102',
#   'chembl387675',
#   'doaklvkfurwedj-rwdrxurgsa-n',
#   'mfcd08282794',
#   'akos005146218',
#   'db00080',
#   'ab0012614',
#   's-7668',
#   '060d533',
#   'sr-01000872587',
#   'q-200927',
#   'sr-01000872587-1',
#   'n-decanoyl-l-tryptophyl-l-asparaginyl-l-aspartyl-l-threonylglycyl-l-ornithyl-l-aspartyl-d-alanyl-l-aspartylglycyl-d-seryl-threo-3-methyl-l-glutamyl-3-anthraniloyl-l-alanine 1.13-3.4-lactone',
#   'n-decanoyl-l-tryptophyl-l-asparaginyl-l-aspartyl-l-threonylglycyl-l-ornithyl-l-aspartyl-d-alanyl-l-aspartylglycyl-d-seryl-threo-3-methyl-l-glutamyl-3-anthraniloyl-l-alanine epsilon(1)-lactone',
#   'n-decanoyl-l-tryptophyl-l-asparaginyl-n-[(3s,6s,9r,15s,18r,21s,24s,30s,31r)-3-[2-(2-aminophenyl)-2-oxoethyl]-24-(3-aminopropyl)-15,21-bis(carboxymethyl)-6-[(2r)-1-carboxypropan-2-yl]-9-(hydroxymethyl)-18,31-dimethyl-2,5,8,11,14,17,20,23,26,29-decaoxo-1-ox']}

# %%
# Retreive all PubChemIDs for each drug #
failed = 0
cid_dict = {}

for drug in smallmolecules:
    url = 'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/' + str(drug) + '/cids/JSON'
    response = requests.get(url)
    try:
        response.json()
    except ValueError:
        continue
    if 'IdentifierList' in response.json().keys():
        cid = response.json()['IdentifierList']['CID'][0]
        cid_dict[drug] = str(cid)
    else:
        failed += 1
    time.sleep(0.50)

print(failed)
print(len(cid_dict))
# Out:
# 757
# 9496

# %%
# Creating a list of small molecule PubChemIDs #
cid_list = []
for k,v in cid_dict.items():
    cid_list.append(v)

# %%
# Retrieving the Molecular Formula, SMILEs string, and InchiKey associated with each PubChemID #
failed = 0
smile_dict = {}
inchikey_dict = {}
molecularformula_dict = {}


for cid in cid_list:
    url ='https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/'+str(cid)+'/property/MolecularFormula,CanonicalSMILES,InChIKey/JSON'
    response = requests.get(url)
    try:
        response.json()
    except ValueError:
        continue
    if 'PropertyTable' in response.json().keys():
        smile = response.json()['PropertyTable']['Properties'][0]['CanonicalSMILES']
        inchikey = response.json()['PropertyTable']['Properties'][0]['InChIKey']
        molecularformula = response.json()['PropertyTable']['Properties'][0]['MolecularFormula']
        smile_dict[cid] = smile
        inchikey_dict[cid] = inchikey
        molecularformula_dict[cid] = molecularformula
        
    else:
        failed += 1
    time.sleep(1)

# %%
# Retrieve DrugBank Accession Numbers for each drug #
drugbank_ids = []
drugbank_names = []

drugbank = open('input/drug links-3.csv')
drugbank_csv = csv.reader(drugbank)
for row in drugbank_csv:
    drugbank_ids.append(row[0])
    drugbank_names.append(row[1].lower())
    
del drugbank_ids[0]
del drugbank_names[0]
                  
drugbank_dict = dict(zip(drugbank_names, drugbank_ids))

# %%
drugbank_dict
# Out:
# {'bivalirudin': 'DB00006',
#  'goserelin': 'DB00014',
#  'gramicidin d': 'DB00027',
#  'desmopressin': 'DB00035',
#  'cetrorelix': 'DB00050',
#  'vasopressin': 'DB00067',
#  'daptomycin': 'DB00080',
#  'ciclosporin': 'DB00091',
#  'felypressin': 'DB00093',
#  'octreotide': 'DB00104',
#  'abarelix': 'DB00106',
#  'pyridoxal phosphate': 'DB00114',
#  'cyanocobalamin': 'DB00115',
#  'tetrahydrofolic acid': 'DB00116',
#  'histidine': 'DB00117',
#  'ademetionine': 'DB00118',
#  'pyruvic acid': 'DB00119',
#  'l-phenylalanine': 'DB00120',
#  'biotin': 'DB00121',
#  'choline': 'DB00122',
#  'l-lysine': 'DB00123',
#  'l-arginine': 'DB00125',
#  'ascorbic acid': 'DB00126',
#  'spermine': 'DB00127',
#  'l-aspartic acid': 'DB00128',
#  'ornithine': 'DB00129',
#  'l-glutamine': 'DB00130',
#  'adenosine phosphate': 'DB00131',
#  'alpha-linolenic acid': 'DB00132',
#  'serine': 'DB00133',
#  'methionine': 'DB00134',
#  'l-tyrosine': 'DB00135',
#  'calcitriol': 'DB00136',
#  'lutein': 'DB00137',
#  'cystine': 'DB00138',
#  'succinic acid': 'DB00139',
#  'riboflavin': 'DB00140',
#  'n-acetylglucosamine': 'DB00141',
#  'glutamic acid': 'DB00142',
#  'glutathione': 'DB00143',
#  'phosphatidyl serine': 'DB00144',
#  'glycine': 'DB00145',
#  'calcifediol': 'DB00146',
#  'pyridoxal': 'DB00147',
#  'creatine': 'DB00148',
#  'l-leucine': 'DB00149',
#  'l-tryptophan': 'DB00150',
#  'l-cysteine': 'DB00151',
#  'thiamine': 'DB00152',
#  'ergocalciferol': 'DB00153',
#  'dihomo-gamma-linolenic acid': 'DB00154',
#  'l-citrulline': 'DB00155',
#  'l-threonine': 'DB00156',
#  'nadh': 'DB00157',
#  'folic acid': 'DB00158',
#  'icosapent': 'DB00159',
#  'l-alanine': 'DB00160',
#  'l-valine': 'DB00161',
#  'vitamin a': 'DB00162',
#  'vitamin e': 'DB00163',
#  'pyridoxine': 'DB00165',
#  'lipoic acid': 'DB00166',
#  'l-isoleucine': 'DB00167',
#  'aspartame': 'DB00168',
#  'cholecalciferol': 'DB00169',
#  'menadione': 'DB00170',
#  'atp': 'DB00171',
#  'proline': 'DB00172',
#  'adenine': 'DB00173',
#  'l-asparagine': 'DB00174',
#  'pravastatin': 'DB00175',
#  'fluvoxamine': 'DB00176',
#  'valsartan': 'DB00177',
#  'ramipril': 'DB00178',
#  'masoprocol': 'DB00179',
#  'flunisolide': 'DB00180',
#  'baclofen': 'DB00181',
#  'amphetamine': 'DB00182',
#  'pentagastrin': 'DB00183',
#  'nicotine': 'DB00184',
#  'cevimeline': 'DB00185',
#  'lorazepam': 'DB00186',
#  'esmolol': 'DB00187',
#  'bortezomib': 'DB00188',
#  'ethchlorvynol': 'DB00189',
#  'carbidopa': 'DB00190',
#  'phentermine': 'DB00191',
#  'indecainide': 'DB00192',
#  'tramadol': 'DB00193',
#  'vidarabine': 'DB00194',
#  'betaxolol': 'DB00195',
#  'fluconazole': 'DB00196',
#  'troglitazone': 'DB00197',
#  'oseltamivir': 'DB00198',
#  'erythromycin': 'DB00199',
#  'hydroxocobalamin': 'DB00200',
#  'caffeine': 'DB00201',
#  'succinylcholine': 'DB00202',
#  'sildenafil': 'DB00203',
#  'dofetilide': 'DB00204',
#  'pyrimethamine': 'DB00205',
#  'reserpine': 'DB00206',
#  'azithromycin': 'DB00207',
#  'ticlopidine': 'DB00208',
#  'trospium': 'DB00209',
#  'adapalene': 'DB00210',
#  'midodrine': 'DB00211',
#  'remikiren': 'DB00212',
#  'pantoprazole': 'DB00213',
#  'torasemide': 'DB00214',
#  'citalopram': 'DB00215',
#  'eletriptan': 'DB00216',
#  'bethanidine': 'DB00217',
#  'moxifloxacin': 'DB00218',
#  'oxyphenonium': 'DB00219',
#  'nelfinavir': 'DB00220',
#  'isoetarine': 'DB00221',
#  'glimepiride': 'DB00222',
#  'diflorasone': 'DB00223',
#  'indinavir': 'DB00224',
#  'gadodiamide': 'DB00225',
#  'guanadrel': 'DB00226',
#  'lovastatin': 'DB00227',
#  'enflurane': 'DB00228',
#  'cefotiam': 'DB00229',
#  'pregabalin': 'DB00230',
#  'temazepam': 'DB00231',
#  'methyclothiazide': 'DB00232',
#  'aminosalicylic acid': 'DB00233',
#  'reboxetine': 'DB00234',
#  'milrinone': 'DB00235',
#  'pipobroman': 'DB00236',
#  'butabarbital': 'DB00237',
#  'nevirapine': 'DB00238',
#  'oxiconazole': 'DB00239',
#  'alclometasone': 'DB00240',
#  'butalbital': 'DB00241',
#  'cladribine': 'DB00242',
#  'ranolazine': 'DB00243',
#  'mesalazine': 'DB00244',
#  'benzatropine': 'DB00245',
#  'ziprasidone': 'DB00246',
#  'methysergide': 'DB00247',
#  'cabergoline': 'DB00248',
#  'idoxuridine': 'DB00249',
#  'dapsone': 'DB00250',
#  'terconazole': 'DB00251',
#  'phenytoin': 'DB00252',
#  'medrysone': 'DB00253',
#  'doxycycline': 'DB00254',
#  'diethylstilbestrol': 'DB00255',
#  'lymecycline': 'DB00256',
#  'clotrimazole': 'DB00257',
#  'calcium acetate': 'DB00258',
#  'sulfanilamide': 'DB00259',
#  'cycloserine': 'DB00260',
#  'anagrelide': 'DB00261',
#  'carmustine': 'DB00262',
#  'sulfisoxazole': 'DB00263',
#  'metoprolol': 'DB00264',
#  'crotamiton': 'DB00265',
#  'dicoumarol': 'DB00266',
#  'cefmenoxime': 'DB00267',
#  'ropinirole': 'DB00268',
#  'chlorotrianisene': 'DB00269',
#  'isradipine': 'DB00270',
#  'diatrizoate': 'DB00271',
#  'betazole': 'DB00272',
#  'topiramate': 'DB00273',
#  'cefmetazole': 'DB00274',
#  'olmesartan': 'DB00275',
#  'amsacrine': 'DB00276',
#  'theophylline': 'DB00277',
#  'argatroban': 'DB00278',
#  'liothyronine': 'DB00279',
#  'disopyramide': 'DB00280',
#  'lidocaine': 'DB00281',
#  'pamidronate': 'DB00282',
#  'clemastine': 'DB00283',
#  'acarbose': 'DB00284',
#  'venlafaxine': 'DB00285',
#  'conjugated estrogens': 'DB00286',
#  'travoprost': 'DB00287',
#  'amcinonide': 'DB00288',
#  'atomoxetine': 'DB00289',
#  'bleomycin': 'DB00290',
#  'chlorambucil': 'DB00291',
#  'etomidate': 'DB00292',
#  'raltitrexed': 'DB00293',
#  'etonogestrel': 'DB00294',
#  'morphine': 'DB00295',
#  'ropivacaine': 'DB00296',
#  'bupivacaine': 'DB00297',
#  'dapiprazole': 'DB00298',
#  'penciclovir': 'DB00299',
#  'tenofovir disoproxil': 'DB00300',
#  'flucloxacillin': 'DB00301',
#  'tranexamic acid': 'DB00302',
#  'ertapenem': 'DB00303',
#  'desogestrel': 'DB00304',
#  'mitomycin': 'DB00305',
#  'talbutal': 'DB00306',
#  'bexarotene': 'DB00307',
#  'ibutilide': 'DB00308',
#  'vindesine': 'DB00309',
#  'chlorthalidone': 'DB00310',
#  'ethoxzolamide': 'DB00311',
#  'pentobarbital': 'DB00312',
#  'valproic acid': 'DB00313',
#  'capreomycin': 'DB00314',
#  'zolmitriptan': 'DB00315',
#  'acetaminophen': 'DB00316',
#  'gefitinib': 'DB00317',
#  'codeine': 'DB00318',
#  'piperacillin': 'DB00319',
#  'dihydroergotamine': 'DB00320',
#  'amitriptyline': 'DB00321',
#  'floxuridine': 'DB00322',
#  'tolcapone': 'DB00323',
#  'fluorometholone': 'DB00324',
#  'nitroprusside': 'DB00325',
#  'calcium glucoheptonate': 'DB00326',
#  'hydromorphone': 'DB00327',
#  'indometacin': 'DB00328',
#  'ethambutol': 'DB00330',
#  'metformin': 'DB00331',
#  'ipratropium': 'DB00332',
#  'methadone': 'DB00333',
#  'olanzapine': 'DB00334',
#  'atenolol': 'DB00335',
#  'nitrofural': 'DB00336',
#  'pimecrolimus': 'DB00337',
#  'omeprazole': 'DB00338',
#  'pyrazinamide': 'DB00339',
#  'metixene': 'DB00340',
#  'cetirizine': 'DB00341',
#  'terfenadine': 'DB00342',
#  'diltiazem': 'DB00343',
#  'protriptyline': 'DB00344',
#  'aminohippuric acid': 'DB00345',
#  'alfuzosin': 'DB00346',
#  'trimethadione': 'DB00347',
#  'nitisinone': 'DB00348',
#  'clobazam': 'DB00349',
#  'minoxidil': 'DB00350',
#  'megestrol acetate': 'DB00351',
#  'tioguanine': 'DB00352',
#  'methylergometrine': 'DB00353',
#  'buclizine': 'DB00354',
#  'aztreonam': 'DB00355',
#  'chlorzoxazone': 'DB00356',
#  'aminoglutethimide': 'DB00357',
#  'mefloquine': 'DB00358',
#  'sulfadiazine': 'DB00359',
#  'sapropterin': 'DB00360',
#  'vinorelbine': 'DB00361',
#  'anidulafungin': 'DB00362',
#  'clozapine': 'DB00363',
#  'sucralfate': 'DB00364',
#  'grepafloxacin': 'DB00365',
#  'doxylamine': 'DB00366',
#  'levonorgestrel': 'DB00367',
#  'norepinephrine': 'DB00368',
#  'cidofovir': 'DB00369',
#  'mirtazapine': 'DB00370',
#  'meprobamate': 'DB00371',
#  'thiethylperazine': 'DB00372',
#  'timolol': 'DB00373',
#  'treprostinil': 'DB00374',
#  'colestipol': 'DB00375',
#  'trihexyphenidyl': 'DB00376',
#  'palonosetron': 'DB00377',
#  'dydrogesterone': 'DB00378',
#  'mexiletine': 'DB00379',
#  'dexrazoxane': 'DB00380',
#  'amlodipine': 'DB00381',
#  'tacrine': 'DB00382',
#  'oxyphencyclimine': 'DB00383',
#  'triamterene': 'DB00384',
#  'valrubicin': 'DB00385',
#  'procyclidine': 'DB00387',
#  'phenylephrine': 'DB00388',
#  'carbimazole': 'DB00389',
#  'digoxin': 'DB00390',
#  'sulpiride': 'DB00391',
#  'profenamine': 'DB00392',
#  'nimodipine': 'DB00393',
#  'beclomethasone dipropionate': 'DB00394',
#  'carisoprodol': 'DB00395',
#  'progesterone': 'DB00396',
#  'phenylpropanolamine': 'DB00397',
#  'sorafenib': 'DB00398',
#  'zoledronic acid': 'DB00399',
#  'griseofulvin': 'DB00400',
#  'nisoldipine': 'DB00401',
#  'eszopiclone': 'DB00402',
#  'ceruletide': 'DB00403',
#  'alprazolam': 'DB00404',
#  'dexbrompheniramine': 'DB00405',
#  'gentian violet cation': 'DB00406',
#  'ardeparin': 'DB00407',
#  'loxapine': 'DB00408',
#  'remoxipride': 'DB00409',
#  'mupirocin': 'DB00410',
#  'carbamoylcholine': 'DB00411',
#  'rosiglitazone': 'DB00412',
#  'pramipexole': 'DB00413',
#  'acetohexamide': 'DB00414',
#  'ampicillin': 'DB00415',
#  'metocurine iodide': 'DB00416',
#  'phenoxymethylpenicillin': 'DB00417',
#  'secobarbital': 'DB00418',
#  'miglustat': 'DB00419',
#  'promazine': 'DB00420',
#  'spironolactone': 'DB00421',
#  'methylphenidate': 'DB00422',
#  'methocarbamol': 'DB00423',
#  'hyoscyamine': 'DB00424',
#  'zolpidem': 'DB00425',
#  'famciclovir': 'DB00426',
#  'triprolidine': 'DB00427',
#  'streptozocin': 'DB00428',
#  'carboprost tromethamine': 'DB00429',
#  'cefpiramide': 'DB00430',
#  'lindane': 'DB00431',
#  'trifluridine': 'DB00432',
#  'prochlorperazine': 'DB00433',
#  'cyproheptadine': 'DB00434',
#  'nitric oxide': 'DB00435',
#  'bendroflumethiazide': 'DB00436',
#  'allopurinol': 'DB00437',
#  'ceftazidime': 'DB00438',
#  'cerivastatin': 'DB00439',
#  'trimethoprim': 'DB00440',
#  'gemcitabine': 'DB00441',
#  'entecavir': 'DB00442',
#  'betamethasone': 'DB00443',
#  'teniposide': 'DB00444',
#  'epirubicin': 'DB00445',
#  'chloramphenicol': 'DB00446',
#  'loracarbef': 'DB00447',
#  'lansoprazole': 'DB00448',
#  'dipivefrin': 'DB00449',
#  'droperidol': 'DB00450',
#  'levothyroxine': 'DB00451',
#  'framycetin': 'DB00452',
#  'clomocycline': 'DB00453',
#  'meperidine': 'DB00454',
#  'loratadine': 'DB00455',
#  'cefalotin': 'DB00456',
#  'prazosin': 'DB00457',
#  'imipramine': 'DB00458',
#  'acitretin': 'DB00459',
#  'verteporfin': 'DB00460',
#  'nabumetone': 'DB00461',
#  'methscopolamine bromide': 'DB00462',
#  'metharbital': 'DB00463',
#  'sodium tetradecyl sulfate': 'DB00464',
#  'ketorolac': 'DB00465',
#  'picrotoxin': 'DB00466',
#  'enoxacin': 'DB00467',
#  'quinine': 'DB00468',
#  'tenoxicam': 'DB00469',
#  'dronabinol': 'DB00470',
#  'montelukast': 'DB00471',
#  'fluoxetine': 'DB00472',
#  'hexylcaine
# <b>limit_output extension: Maximum message size of 10000 exceeded with 27456 characters</b>

# %% [markdown]
# ### Creating a DataFrame with all DrugBank Small Molecule Attributes
# #### Output File : drugbank_smallmolecule_attributes.csv

# %%
df = pd.DataFrame()
df = df.append(smallmolecules)
df.columns = ['DrugBank Small Molecules']

# %%
# Add synonyms to dataframe #
synonyms = []

for index, row in df.iterrows():
    drugname = row.loc['DrugBank Small Molecules']
    if drugname in synonym_dict:
        synonyms.append(synonym_dict[drugname][1:])
    else:
        synonyms.append(None)
df.loc[:,'Synonyms'] = pd.Series(np.array(synonyms), index=df.index)

# %%
# Add PubChemIDs to dataframe #
pcids = []

for index,row in df.iterrows():
    drug = row.loc['DrugBank Small Molecules']
    if drug in cid_dict:
        pcids.append(cid_dict[drug])
    else:
        pcids.append(None)
df.loc[:,'PubChemID'] = pd.Series(np.array(pcids), index=df.index)

# %%
# Add SMILEs strings to dataframe #
SMILEs = []

for index, row in df.iterrows():
    pcid = row.loc['PubChemID']
    if pcid in smile_dict:
         SMILEs.append(smile_dict[pcid])
    else:  
        SMILEs.append(None)
        
df.loc[:,'SMILEs'] = pd.Series(np.array(SMILEs), index=df.index)

# %%
# Add InChIKeys to dataframe #
InChIkeys = []

for index, row in df.iterrows():
    pcid = row.loc['PubChemID']
    if pcid in inchikey_dict:
        InChIkeys.append(inchikey_dict[pcid])
    else:
        InChIkeys.append(None)
df.loc[:,'InChIkeys'] = pd.Series(np.array(InChIkeys), index=df.index)

# %%
# Add Molecular Formulas to dataframe #
MFs = []

for index, row in df.iterrows():
    pcid = row.loc['PubChemID']
    if pcid in molecularformula_dict:
        MFs.append(molecularformula_dict[pcid])
    else:
        MFs.append(None)
df.loc[:,'Molecular Formula'] = pd.Series(np.array(MFs),index=df.index)

# %%
# Add DrugBank Accession Numbers to dataframe #
AccNumber = []
for index, row in df.iterrows():
    drugname = row.loc['DrugBank Small Molecules']
    if drugname in drugbank_dict:
         AccNumber.append(drugbank_dict[drugname])
    else:  
        df.drop(index, inplace = True)    
df.loc[:,'DB_Accession_Numbers'] = pd.Series(np.array(AccNumber), index=df.index)

# %%
df
# Out:
#                                 DrugBank Small Molecules  \
# 0                                            bivalirudin
# 1                                              goserelin
# 2                                           gramicidin d
# 3                                           desmopressin
# 4                                             cetrorelix
# 5                                            vasopressin
# 6                                             daptomycin
# 7                                            ciclosporin
# 8                                            felypressin
# 9                                             octreotide
# 10                                              abarelix
# 11                                   pyridoxal phosphate
# 12                                        cyanocobalamin
# 13                                  tetrahydrofolic acid
# 14                                             histidine
# 15                                          ademetionine
# 16                                          pyruvic acid
# 17                                       l-phenylalanine
# 18                                                biotin
# 19                                               choline
# 20                                              l-lysine
# 21                                            l-arginine
# 22                                         ascorbic acid
# 23                                              spermine
# 24                                       l-aspartic acid
# 25                                             ornithine
# 26                                           l-glutamine
# 27                                   adenosine phosphate
# 28                                  alpha-linolenic acid
# 29                                                serine
# ...                                                  ...
# 10224                            norethindrone enanthate
# 10225                               quingestanol acetate
# 10226                                  combretastatin a4
# 10227                                          cortisone
# 10228                                        dextrorphan
# 10229                                   prezatide copper
# 10230                              calcium polycarbophil
# 10231                                ferric oxyhydroxide
# 10232  ethyl 8-hydroxy-alpha-(2-propynylamino)-5-quin...
# 10233                                sodium metavanadate
# 10234                    dexamethasone metasulfobenzoate
# 10235                                            ribitol
# 10236                                        ceramide ap
# 10237                                        ceramide ng
# 10238                                    tosylchloramide
# 10239                                       tenivastatin
# 10240                                          cinazepam
# 10241                                         clonazolam
# 10242                                         nitrazolam
# 10243                                          pyrazolam
# 10244                                         bentazepam
# 10245                                        brovanexine
# 10246                                            mk-1454
# 10247                                           adu-s100
# 10248                                      larotrectinib
# 10249                                 cefamandole nafate
# 10250                                         dabigatran
# 10251                           riboflavin tetrabutyrate
# 10252                                            mebenil
# 10253                                       rebeccamycin
#
#                                                 Synonyms  PubChemID  \
# 0      [128270-60-0, angiomax, hirulog, bivalirudina,...   16129704
# 1      [goserelin acetate, zoladex, 65807-02-5, decap...    5311128
# 2                                                   None       None
# 3      [16679-58-6, desmopresina, desmopressine, unii...    5311065
# 4      [120287-85-6, cetrorelix acetate, cetrorelixum...   25074887
# 5                                                   None       None
# 6      [103060-53-3, cubicin, cidecin, daptomicina, d...   16134395
# 7      [cyclosporine, ciclosporin, 59865-13-3, cyclos...    5284373
# 8      [plv-2, felypressine, felypressinum, felipresi...   14257662
# 9      [octreotide acetate, 83150-76-9, octreotidum, ...     448601
# 10     [plenaxis, 183552-38-7, ppi-149, plenaxis depo...   16131215
# 11     [codecarboxylase, pyridoxal 5-phosphate, 54-47...       1051
# 12     [cyanocobalamin, 68-19-9, cobalamin, cyanocoba...    5311498
# 13     [135-16-0, tetrahydrofolate, tetrahydropteroyl...  135444742
# 14     [histidine, 71-00-1, h-his-oh, glyoxaline-5-al...       6274
# 15     [s-adenosyl-l-methionine, adomet, s-adenosylme...      34755
# 16     [2-oxopropanoic acid, 127-17-3, 2-oxopropionic...       1060
# 17     [phenylalanine, 63-91-2, (s)-2-amino-3-phenylp...       6140
# 18     [d-biotin, vitamin h, 58-85-5, vitamin b7, coe...     171548
# 19     [choline ion, bilineurine, choline cation, cho...        305
# 20     [lysine, 56-87-1, h-lys-oh, lysine acid, (s)-l...       5962
# 21     [arginine, 74-79-3, l-(+)-arginine, l(+)-argin...       6322
# 22     [ascorbic acid, vitamin c, 50-81-7, l(+)-ascor...   54670067
# 23     [71-44-3, neuridine, gerontine, musculamine, s...       1103
# 24     [aspartic acid, 56-84-8, h-asp-oh, l-aspartate...       5960
# 25     [ornithine, 70-26-8, (s)-2,5-diaminopentanoic ...       6262
# 26     [glutamine, 56-85-9, levoglutamide, h-gln-oh, ...       5961
# 27     [5'-adenylic acid, adenosine monophosphate, 61...       6083
# 28     [alpha-linolenic acid, 463-40-1, linolenate, (...    5280934
# 29     [serine, 56-45-1, (s)-2-amino-3-hydroxypropano...       5951
# ...                                                  ...        ...
# 10224  [3836-23-5, noristerat, norethisterone enantat...     229295
# 10225  [unii-m33ggz63kg, 3000-39-3, quingestanol acet...      18142
# 10226  [117048-59-6, combretastatin a-4, combretastat...    5351344
# 10227  [53-06-5, kendall's compound e, andreson, cort...     222786
# 10228  [dextrorphane, dextrorphanum, d-3-hydroxy-n-me...    5360697
# 10229  [unii-6bjq43t1i9, 6bjq43t1i9, 89030-95-5, ghk ...   71587328
# 10230                                               None       None
# 10231                                               None       None
# 10232  [m-31, ethyl 8-hydroxy-alpha-(2-propynylamino)...   10424768
# 10233  [13718-26-8, sodium vanadate(v), vanadic acid,...    4148882
# 10234                                               None       None
# 10235  [ribitol, adonitol, xylite, d-xylitol, 87-99-0...       6912
# 10236  [cer(t18:0/18:0(2oh)), n-(2-hydroxyoctadecanoy...   44625889
# 10237                                               None       None
# 10238                                               None       None
# 10239  [tenivastatin, 121009-77-6, unii-9l6m5th46b, d...      64718
# 10240  [172986-25-3, butanedioic acid, mono(7-bromo-5...     629281
# 10241  [unii-hjh52yyc1x, hjh52yyc1x, 33887-02-4, sche...   12317881
# 10242  [k499dbb308, 28910-99-8, nitrazolam, 4h-(1,2,4...   20317278
# 10243  [39243-02-2, unii-8lh16383pk, 8lh16383pk, 8-br...   12562545
# 10244  [thiadipone, tiadipone, bentazepam [usan:inn],...  135412795
# 10245  [unii-y00sd533iw, y00sd533iw, 54340-61-3, brov...     162137
# 10246                                               None       None
# 10247                                               None       None
# 10248  [larotrectinib, 1223403-58-4, arry-470, unii-p...   46188928
# 10249  [42540-40-9, cephamandole nafate, cefamandol n...   23665731
# 10250  [211914-51-1, bibr 953, bibr953, bibr-953, che...     216210
# 10251  [unii-f211c9msgy, hibon, ccris 5849, 752-56-7,...      92140
# 10252  [2-methyl-n-phenylbenzamide, 2-methylbenzanili...      23466
# 10253  [93908-02-2, nsc 359079, brn 4732638, unii-y96...      73110
#
#                                                   SMILEs  \
# 0      CCC(C)C(C(=O)N1CCCC1C(=O)NC(CCC(=O)O)C(=O)NC(C...
# 1      CC(C)CC(C(=O)NC(CCCN=C(N)N)C(=O)N1CCCC1C(=O)NN...
# 2                                                   None
# 3      C1CC(N(C1)C(=O)C2CSSCCC(=O)NC(C(=O)NC(C(=O)NC(...
# 4      CC(C)CC(C(=O)NC(CCCN=C(N)N)C(=O)N1CCCC1C(=O)NC...
# 5                                                   None
# 6      CCCCCCCCCC(=O)NC(CC1=CNC2=CC=CC=C21)C(=O)NC(CC...
# 7      CCC1C(=O)N(CC(=O)N(C(C(=O)NC(C(=O)N(C(C(=O)NC(...
# 8      C1CC(N(C1)C(=O)C2CSSCC(C(=O)NC(C(=O)NC(C(=O)NC...
# 9      CC(C1C(=O)NC(CSSCC(C(=O)NC(C(=O)NC(C(=O)NC(C(=...
# 10     CC(C)CC(C(=O)NC(CCCCNC(C)C)C(=O)N1CCCC1C(=O)NC...
# 11                       CC1=NC=C(C(=C1O)C=O)COP(=O)(O)O
# 12     CC1=CC2=C(C=C1C)N(C=N2)C3C(C(C(O3)CO)OP(=O)([O...
# 13     C1C(NC2=C(N1)N=C(NC2=O)N)CNC3=CC=C(C=C3)C(=O)N...
# 14                                C1=C(NC=N1)CC(C(=O)O)N
# 15     C[S+](CCC(C(=O)[O-])N)CC1C(C(C(O1)N2C=NC3=C2N=...
# 16                                          CC(=O)C(=O)O
# 17                              C1=CC=C(C=C1)CC(C(=O)O)N
# 18                        C1C2C(C(S1)CCCCC(=O)O)NC(=O)N2
# 19                                        C[N+](C)(C)CCO
# 20                                     C(CCN)CC(C(=O)O)N
# 21                                C(CC(C(=O)O)N)CN=C(N)N
# 22                            C(C(C1C(=C(C(=O)O1)O)O)O)O
# 23                                      C(CCNCCCN)CNCCCN
# 24                                   C(C(C(=O)O)N)C(=O)O
# 25                                      C(CC(C(=O)O)N)CN
# 26                                  C(CC(=O)N)C(C(=O)O)N
# 27      C1=NC2=C(C(=N1)N)N=CN2C3C(C(C(O3)COP(=O)(O)O)O)O
# 28                            CCC=CCC=CCC=CCCCCCCCC(=O)O
# 29                                        C(C(C(=O)O)N)O
# ...
# <b>limit_output extension: Maximum message size of 10000 exceeded with 17870 characters</b>

# %%
df.to_csv('/Users/maayanlab/Documents/DrugSetEnrichment/Drugsetlibraries/Drugbank/Small molecules/drugbank_smallmolecule_attributes.csv')
